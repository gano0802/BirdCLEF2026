# %% [markdown]
# <a href="https://colab.research.google.com/github/gano0802/BirdCLEF2026/blob/main/BC2026_Distilled_SED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/bin/bash
# !kaggle datasets download tuckerarrants/birdclef-2026-waveform-cache

# %%
# !cp -r /content/birdclef-2026-waveform-cache.zip /content/drive/MyDrive/kaggle/Birdclef2026/input

# %%
# import os
# # Create the destination directory if it doesn't exist
# output_dir = '/content/drive/MyDrive/kaggle/Birdclef2026/input/birdclef-2026-waveform-cache'
# os.makedirs(output_dir, exist_ok=True)

# # Unzip the file into the specified directory
# !unzip -q /content/birdclef-2026-waveform-cache.zip -d "{output_dir}"

# %%
# !unzip /content/drive/MyDrive/kaggle/Birdclef2026/input/birdclef-2026-waveform-cache.zip -d /content
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2425_S01_20240318_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2426_S01_20240318_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2427_S01_20240318_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2428_S01_20240319_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2429_S01_20240320_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2430_S01_20240320_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2431_S01_20240320_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2432_S01_20240320_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2433_S01_20240321_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2434_S01_20240321_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2435_S01_20240321_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2436_S01_20240322_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2437_S01_20240322_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2438_S01_20240322_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2439_S01_20240322_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2440_S01_20240322_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2441_S01_20240323_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2442_S01_20240323_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2443_S01_20240324_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2444_S01_20240324_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2445_S01_20240324_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2446_S01_20240325_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2447_S01_20240325_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2448_S01_20240326_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2449_S01_20240326_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2450_S01_20240326_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2451_S01_20240326_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2452_S01_20240326_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2453_S01_20240326_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2454_S01_20240328_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2455_S01_20240328_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2456_S01_20240328_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2457_S01_20240328_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2458_S01_20240328_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2459_S01_20240329_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2460_S01_20240329_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2461_S01_20240330_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2462_S01_20240330_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2463_S01_20240330_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2464_S01_20240330_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2465_S01_20240330_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2466_S01_20240331_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2467_S01_20240331_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2468_S01_20240331_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2469_S01_20240331_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2470_S01_20240331_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2471_S01_20240331_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2472_S01_20240331_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2473_S01_20240331_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2474_S01_20240401_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2475_S01_20240401_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2476_S01_20240401_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2477_S01_20240401_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2478_S01_20240401_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2479_S01_20240401_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2480_S01_20240402_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2481_S01_20240402_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2482_S01_20240402_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2483_S01_20240402_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2484_S01_20240402_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2485_S01_20240403_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2486_S01_20240403_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2487_S01_20240403_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2488_S01_20240403_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2489_S01_20240403_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2490_S01_20240404_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2491_S01_20240405_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2492_S01_20240405_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2493_S01_20240405_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2494_S01_20240405_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2495_S01_20240405_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2496_S01_20240405_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2497_S01_20240406_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2498_S01_20240406_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2499_S01_20240406_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2500_S01_20240407_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2501_S01_20240407_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2502_S01_20240407_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2503_S01_20240407_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2504_S01_20240407_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2505_S01_20240407_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2506_S01_20240407_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2507_S01_20240407_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2508_S01_20240407_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2509_S01_20240407_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2510_S01_20240408_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2511_S01_20240409_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2512_S01_20240409_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2513_S01_20240409_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2514_S01_20240409_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2515_S01_20240409_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2516_S01_20240410_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2517_S01_20240410_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2518_S01_20240410_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2519_S01_20240410_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2520_S01_20240410_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2521_S01_20240411_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2522_S01_20240411_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2523_S01_20240411_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2524_S01_20240411_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2525_S01_20240411_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2526_S01_20240412_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2527_S01_20240412_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2528_S01_20240412_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2529_S01_20240412_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2530_S01_20240412_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2531_S01_20240413_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2532_S01_20240413_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2533_S01_20240413_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2534_S01_20240413_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2535_S01_20240413_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2536_S01_20240413_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2537_S01_20240413_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2538_S01_20240414_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2539_S01_20240414_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2540_S01_20240414_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2541_S01_20240414_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2542_S01_20240414_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2543_S01_20240414_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2544_S01_20240414_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2545_S01_20240414_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2546_S01_20240414_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2547_S01_20240415_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2548_S01_20240415_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2549_S01_20240415_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2550_S01_20240415_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2551_S01_20240415_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2552_S01_20240416_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2553_S01_20240416_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2554_S01_20240417_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2555_S01_20240417_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2556_S01_20240417_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2557_S01_20240417_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2558_S01_20240418_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2559_S01_20240418_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2560_S01_20240418_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2561_S01_20240418_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2562_S01_20240419_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2563_S01_20240419_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2564_S01_20240419_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2565_S01_20240420_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2566_S01_20240420_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2567_S01_20240420_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2568_S01_20240420_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2569_S01_20240420_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2570_S01_20240420_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2571_S01_20240420_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2572_S01_20240421_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2573_S01_20240421_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2574_S01_20240422_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2575_S01_20240422_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2576_S01_20240422_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2577_S01_20240422_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2578_S01_20240422_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2579_S01_20240422_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2580_S01_20240422_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2581_S01_20240422_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2582_S01_20240423_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2583_S01_20240424_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2584_S01_20240424_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2585_S01_20240424_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2586_S01_20240424_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2587_S01_20240425_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2588_S01_20240425_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2589_S01_20240426_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2590_S01_20240426_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2591_S01_20240427_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2592_S01_20240427_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2593_S01_20240427_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2594_S01_20240427_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2595_S01_20240427_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2596_S01_20240427_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2597_S01_20240428_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2598_S01_20240428_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2599_S01_20240428_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2600_S01_20240428_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2601_S01_20240428_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2602_S01_20240428_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2603_S01_20240428_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2604_S01_20240428_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2605_S01_20240428_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2606_S01_20240428_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2607_S01_20240428_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2608_S01_20240429_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2609_S01_20240429_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2610_S01_20240429_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2611_S01_20240429_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2612_S01_20240429_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2613_S01_20240429_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2614_S01_20240430_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2615_S01_20240430_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2616_S01_20240430_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2617_S01_20240430_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2618_S01_20240430_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2619_S01_20240430_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2620_S02_20210919_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2621_S02_20210919_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2622_S02_20210919_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2623_S02_20210920_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2624_S02_20210920_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2625_S02_20210920_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2626_S02_20210920_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2627_S02_20210920_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2628_S02_20210920_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2629_S02_20210921_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2630_S02_20210921_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2631_S02_20210921_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2632_S02_20210922_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2633_S02_20210922_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2634_S02_20210922_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2635_S02_20210923_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2636_S02_20210924_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2637_S02_20210924_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2638_S02_20210924_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2639_S02_20210925_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2640_S02_20210926_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2641_S02_20210926_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2642_S02_20210927_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2643_S02_20210927_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2644_S02_20210928_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2645_S02_20210928_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2646_S02_20210929_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2647_S02_20210929_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2648_S02_20210929_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2649_S02_20210929_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2650_S02_20210929_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2651_S02_20210930_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2652_S02_20210930_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2653_S02_20210930_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2654_S02_20210930_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2655_S02_20210930_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2656_S02_20211001_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2657_S02_20211001_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2658_S02_20211001_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2659_S02_20211001_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2660_S02_20211002_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2661_S02_20211002_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2662_S02_20211003_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2663_S02_20211003_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2664_S02_20211004_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2665_S02_20211004_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2666_S02_20211004_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2667_S02_20211005_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2668_S02_20211005_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2669_S02_20211005_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2670_S02_20211005_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2671_S02_20211005_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2672_S02_20211005_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2673_S02_20211005_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2674_S02_20211005_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2675_S02_20211006_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2676_S02_20211006_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2677_S02_20211006_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2678_S02_20211007_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2679_S02_20211008_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2680_S02_20211008_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2681_S02_20211008_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2682_S02_20211008_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2683_S02_20211008_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2684_S02_20211008_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2685_S02_20211008_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2686_S02_20211008_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2687_S02_20211008_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2688_S02_20211009_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2689_S02_20211009_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2690_S02_20211009_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2691_S02_20211009_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2692_S02_20211009_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2693_S02_20211009_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2694_S02_20211009_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2695_S02_20211009_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2696_S02_20211010_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2697_S02_20211010_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2698_S02_20211010_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2699_S02_20211010_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2700_S02_20211010_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2701_S02_20211010_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2702_S02_20211010_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2703_S02_20211011_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2704_S02_20211011_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2705_S02_20211012_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2706_S02_20211012_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2707_S02_20211012_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2708_S02_20211012_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2709_S02_20211012_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2710_S02_20211013_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2711_S02_20211013_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2712_S02_20211013_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2713_S02_20211013_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2714_S02_20211013_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2715_S02_20211013_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2716_S02_20211014_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2717_S02_20211014_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2718_S02_20211015_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2719_S02_20211015_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2720_S02_20211016_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2721_S02_20211016_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2722_S02_20211016_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2723_S02_20211016_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2724_S02_20211016_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2725_S02_20211016_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2726_S02_20211016_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2727_S02_20211017_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2728_S02_20211017_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2729_S02_20211017_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2730_S02_20211017_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2731_S02_20211018_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2732_S02_20211018_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2733_S02_20211018_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2734_S02_20211019_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2735_S02_20211019_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2736_S02_20211019_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2737_S02_20211019_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2738_S02_20211019_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2739_S02_20211020_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2740_S02_20211020_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2741_S02_20211021_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2742_S02_20211021_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2743_S02_20211021_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2744_S02_20211022_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2745_S02_20211022_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2746_S02_20211022_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2747_S02_20211022_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2748_S02_20211022_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2749_S02_20211022_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2750_S02_20211023_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2751_S02_20211024_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2752_S02_20211024_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2753_S02_20211024_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2754_S02_20211024_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2755_S02_20211025_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2756_S02_20211025_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2757_S02_20211025_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2758_S02_20211026_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2759_S02_20211026_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2760_S02_20211026_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2761_S02_20211027_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2762_S02_20211028_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2763_S02_20211028_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2764_S02_20211028_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2765_S02_20211029_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2766_S02_20211029_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2767_S02_20211030_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2768_S02_20211030_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2769_S02_20211030_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2770_S02_20211030_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2771_S02_20211031_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2772_S02_20211101_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2773_S02_20211101_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2774_S02_20211101_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2775_S02_20211101_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2776_S02_20211102_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2777_S02_20211102_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2778_S02_20211102_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2779_S02_20211102_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2780_S02_20211102_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2781_S02_20211102_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2782_S02_20211102_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2783_S02_20211103_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2784_S02_20211103_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2785_S02_20211103_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2786_S02_20211103_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2787_S02_20211103_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2788_S02_20211103_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2789_S02_20211104_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2790_S02_20211104_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2791_S02_20211105_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2792_S02_20211105_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2793_S02_20211105_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2794_S02_20211105_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2795_S02_20211106_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2796_S02_20211106_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2797_S02_20211106_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2798_S02_20211107_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2799_S02_20211107_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2800_S02_20211107_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2801_S02_20211108_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2802_S02_20211108_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2803_S02_20211108_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2804_S02_20211108_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2805_S02_20211109_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2806_S02_20211109_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2807_S02_20211109_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2808_S02_20211110_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2809_S02_20211110_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2810_S02_20211110_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2811_S02_20211110_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2812_S02_20211110_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2813_S02_20211110_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2814_S02_20211110_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2815_S02_20211110_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2816_S02_20211110_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2817_S02_20211110_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2818_S02_20211111_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2819_S02_20211111_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2820_S02_20211112_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2821_S02_20211112_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2822_S02_20211112_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2823_S02_20211112_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2824_S02_20211112_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2825_S02_20211112_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2826_S02_20211112_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2827_S02_20211113_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2828_S02_20211113_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2829_S02_20211113_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2830_S02_20211113_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2831_S02_20211113_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2832_S02_20211113_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2833_S02_20211114_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2834_S02_20211114_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2835_S02_20211114_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2836_S02_20211115_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2837_S02_20211115_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2838_S02_20211116_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2839_S02_20211116_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2840_S02_20211117_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2841_S02_20211117_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2842_S02_20211117_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2843_S02_20211117_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2844_S02_20211117_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2845_S02_20211118_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2846_S02_20211118_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2847_S02_20211118_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2848_S02_20211118_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2849_S02_20211119_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2850_S02_20211119_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2851_S02_20211119_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2852_S02_20211119_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2853_S02_20211119_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2854_S02_20211119_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2855_S02_20211119_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2856_S02_20211120_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2857_S02_20211120_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2858_S02_20211120_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2859_S02_20211120_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2860_S02_20211121_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2861_S02_20211121_174500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2862_S02_20211121_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2863_S02_20211122_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2864_S02_20211123_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2865_S02_20211123_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2866_S02_20211123_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2867_S02_20211124_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2868_S02_20211124_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2869_S02_20211124_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2870_S02_20211124_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2871_S02_20211125_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2872_S02_20211125_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2873_S02_20211125_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2874_S02_20211126_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2875_S02_20211126_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2876_S02_20211127_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2877_S02_20211127_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2878_S02_20211128_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2879_S02_20211128_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2880_S02_20211128_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2881_S02_20211128_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2882_S02_20211128_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2883_S02_20211129_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2884_S02_20211130_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2885_S02_20211130_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2886_S02_20211130_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2887_S02_20211130_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2888_S02_20211201_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2889_S02_20211201_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2890_S02_20211201_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2891_S02_20211201_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2892_S02_20211201_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2893_S02_20211201_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2894_S02_20211202_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2895_S02_20211202_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2896_S02_20211203_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2897_S02_20211203_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2898_S02_20211203_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2899_S02_20211203_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2900_S02_20211203_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2901_S02_20211203_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2902_S02_20211203_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2903_S02_20211203_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2904_S02_20211203_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2905_S02_20211204_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2906_S02_20211204_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2907_S02_20211204_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2908_S02_20211204_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2909_S02_20211204_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2910_S02_20211205_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2911_S02_20211205_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2912_S02_20211205_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2913_S02_20211205_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2914_S02_20211205_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2915_S02_20211205_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2916_S02_20211205_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2917_S02_20211205_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2918_S02_20211206_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2919_S02_20211206_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2920_S02_20211207_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2921_S02_20211207_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2922_S02_20211208_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2923_S02_20211209_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2924_S02_20211209_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2925_S02_20211209_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2926_S02_20211209_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2927_S02_20211209_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2928_S02_20211210_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2929_S02_20211210_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2930_S02_20211210_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2931_S02_20211210_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2932_S02_20211211_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2933_S02_20211211_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_2934_S02_20211211_223000.pt
# ...
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7255_S22_20211028_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7256_S22_20211028_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7257_S22_20211029_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7258_S22_20211029_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7259_S22_20211029_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7260_S22_20211029_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7261_S22_20211029_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7262_S22_20211030_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7263_S22_20211030_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7264_S22_20211030_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7265_S22_20211030_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7266_S22_20211030_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7267_S22_20211031_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7268_S22_20211031_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7269_S22_20211031_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7270_S22_20211031_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7271_S22_20211101_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7272_S22_20211101_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7273_S22_20211101_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7274_S22_20211101_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7275_S22_20211101_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7276_S22_20211101_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7277_S22_20211101_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7278_S22_20211101_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7279_S22_20211101_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7280_S22_20211102_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7281_S22_20211103_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7282_S22_20211103_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7283_S22_20211103_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7284_S22_20211103_040000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7285_S22_20211103_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7286_S22_20211103_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7287_S22_20211103_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7288_S22_20211103_224500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7289_S22_20211103_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7290_S22_20211104_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7291_S22_20211104_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7292_S22_20211104_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7293_S22_20211104_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7294_S22_20211104_184500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7295_S22_20211104_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7296_S22_20211104_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7297_S22_20211105_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7298_S22_20211105_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7299_S22_20211105_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7300_S22_20211105_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7301_S22_20211105_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7302_S22_20211106_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7303_S22_20211106_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7304_S22_20211106_213000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7305_S22_20211106_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7306_S22_20211107_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7307_S22_20211107_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7308_S22_20211107_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7309_S22_20211107_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7310_S22_20211107_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7311_S22_20211108_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7312_S22_20211108_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7313_S22_20211108_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7314_S22_20211108_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7315_S22_20211108_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7316_S22_20211108_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7317_S22_20211108_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7318_S22_20211109_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7319_S22_20211109_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7320_S22_20211109_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7321_S22_20211109_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7322_S22_20211109_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7323_S22_20211109_233000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7324_S22_20211110_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7325_S22_20211110_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7326_S22_20211110_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7327_S22_20211110_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7328_S22_20211111_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7329_S22_20211111_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7330_S22_20211112_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7331_S22_20211112_011500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7332_S22_20211112_014500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7333_S22_20211112_193000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7334_S22_20211112_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7335_S22_20211113_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7336_S22_20211113_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7337_S22_20211113_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7338_S22_20211113_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7339_S22_20211113_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7340_S22_20211113_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7341_S22_20211114_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7342_S22_20211114_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7343_S22_20211114_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7344_S22_20211114_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7345_S22_20211114_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7346_S22_20211115_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7347_S22_20211115_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7348_S22_20211115_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7349_S22_20211115_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7350_S22_20211115_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7351_S22_20211115_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7352_S22_20211115_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7353_S22_20211115_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7354_S22_20211116_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7355_S22_20211116_020000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7356_S22_20211116_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7357_S22_20211116_034500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7358_S22_20211116_180000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7359_S22_20211116_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7360_S22_20211116_210000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7361_S22_20211116_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7362_S22_20211117_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7363_S22_20211117_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7364_S22_20211117_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7365_S22_20211117_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7366_S22_20211117_234500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7367_S22_20211118_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7368_S22_20211118_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7369_S22_20211118_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7370_S22_20211118_021500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7371_S22_20211118_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7372_S22_20211118_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7373_S22_20211118_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7374_S22_20211118_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7375_S22_20211119_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7376_S22_20211119_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7377_S22_20211119_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7378_S22_20211119_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7379_S22_20211120_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7380_S22_20211120_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7381_S22_20211120_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7382_S22_20211120_200000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7383_S22_20211120_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7384_S22_20211120_221500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7385_S22_20211120_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7386_S22_20211121_223000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7387_S22_20211122_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7388_S22_20211122_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7389_S22_20211122_190000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7390_S22_20211122_191500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7391_S22_20211122_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7392_S22_20211122_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7393_S22_20211122_230000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7394_S22_20211123_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7395_S22_20211123_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7396_S22_20211123_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7397_S22_20211124_001500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7398_S22_20211124_003000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7399_S22_20211124_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7400_S22_20211124_194500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7401_S22_20211124_231500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7402_S22_20211125_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7403_S22_20211125_030000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7404_S22_20211125_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7405_S22_20211126_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7406_S22_20211126_033000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7407_S22_20211126_181500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7408_S22_20211126_214500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7409_S22_20211127_004500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7410_S22_20211127_010000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7411_S22_20211127_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7412_S22_20211127_183000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7413_S22_20211127_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7414_S22_20211127_211500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7415_S22_20211127_220000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7416_S22_20211128_013000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7417_S22_20211128_023000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7418_S22_20211128_024500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7419_S22_20211128_031500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7420_S22_20211128_201500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7421_S22_20211128_203000.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7422_S22_20211128_204500.pt
#   inflating: /content/waveform_cache/soundscape/sc_BC2026_Train_7423_S22_20211129_010000.pt  error:  zipfile read error

# %%
# !cp -r /content/drive/MyDrive/kaggle/Birdclef2026/input/birdclef-2026-waveform-cache.zip /content/

# %% [markdown]
# # S1 -- IMPORTS + CONFIG

# %%
EXP = "exp03"

# %%
# =================================================================
# S1 -- IMPORTS + CONFIG
# =================================================================
import os, sys, time, json, pickle, gc, random, math
import numpy as np
import pandas as pd
from pathlib import Path
from collections import defaultdict

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from torch.cuda.amp import GradScaler, autocast
import torchaudio
import timm
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from scipy.special import expit as sigmoid_np
from tqdm.notebook import tqdm, trange
import warnings
warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True # False
torch.backends.cudnn.benchmark = False # True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
if torch.cuda.is_available(): print(f"GPU: {torch.cuda.get_device_name()}")

# ------------------------------------------------------------------
# Notebook Mode
# -----------------------------------------------------------------
MODE = "train"  # "train" or "infer"

if MODE == 'train':    #Kaggle struggles with full training pipeline
    DEBUG = False
else:
    DEBUG = False

# ------------------------------------------------------------------
# Paths -- Kaggle dataset layout
# -----------------------------------------------------------------
COMP_DIR = Path("/content/drive/MyDrive/kaggle/Birdclef2026")
WAVEFORM_CACHE_DIR = Path("/content/waveform_cache")
PERCH_ONNX_PATH = Path("/content/drive/MyDrive/kaggle/Birdclef2026/input/perch-v2-no-dft-onnx/perch_v2_no_dft.onnx")

LABELS_PATH     = COMP_DIR / "input" / "train_soundscapes_labels.csv"
TAXONOMY_PATH   = COMP_DIR / "input" / "taxonomy.csv"
SAMPLE_SUB_PATH = COMP_DIR / "input" / "sample_submission.csv"
TEST_DIR        = COMP_DIR / "input" / "test_soundscapes"

OUT_DIR = Path("/content/drive/MyDrive/kaggle/Birdclef2026/outputs")

NUM_CLASSES = 234
SR = 32000

# --- Duration ---
TRAIN_DURATION = 5    # seconds
VAL_DURATION   = 5    # always 5s for competition eval
TRAIN_SAMPLES  = SR * TRAIN_DURATION
VAL_SAMPLES    = SR * VAL_DURATION

N_FOLDS = 5

# --- Mel spectrogram ---
N_FFT      = 2048
HOP_LENGTH = 512
N_MELS     = 256
FMIN       = 20
FMAX       = 16000

# --- Model ---
BACKBONE_NAME = "tf_efficientnet_b0.ns_jft_in1k"

# --- Perch distillation ---
USE_PERCH_DISTILL = True
PERCH_EMBED_DIM   = 1536
ALPHA_DISTILL     = 1.0   # MSE loss weight

# --- Training ---
FOLDS  = [0, 1, 2, 3, 4]
EPOCHS = 25
BATCH  = 16 if DEBUG else 64        # used 64 locally, 16 for Kaggle
LR     = 5e-4
MIN_LR = 1e-5
WD     = 1e-4
WARMUP_EPOCHS = 2

# --- Upsampling ---
MIN_SAMPLE = 20

# --- Augmentation ---
AUG_PROB = 0.5
AUG_GAIN_DB_RANGE      = (-6.0, 6.0)
AUG_NOISE_SNR_DB_RANGE = (10.0, 30.0)
AUG_SHIFT_SAMPLES_MAX  = int(SR * 0.5)

# --- MixUp ---
USE_FOCAL_MIXUP    = True
MIXUP_PROB         = 0.5
MIXUP_ALPHA        = 0.4
MIXUP_HARD         = True    # union labels (hard) vs weighted blend (soft)

USE_FOCAL_SC_MIXUP     = True
FOCAL_SC_MIXUP_PROB    = 0.5
FOCAL_SC_MIXUP_ALPHA   = 0.4

# --- FreqMixStyle (disabled by default) ---
FREQ_MIXSTYLE_PROB  = 0.0
FREQ_MIXSTYLE_ALPHA = 0.1

# --- SpecAugment ---
FREQ_MASK_PARAM = 10
TIME_MASK_PARAM = 10
NUM_FREQ_MASKS  = 1
NUM_TIME_MASKS  = 2

# --- Source weights ---
USE_FOCAL           = True
USE_FOCAL_SECONDARY = True
USE_LABELED_SC      = True

ACTIVE_SOURCES = ["focal", "sc"]
SHARES = {"focal": 0.9, "sc": 0.1}
SOURCE_WEIGHTS = {
    "focal":         1.0,
    "focal_missing": 0.0,
    "sc":            1.0,
}

print(f"Backbone: {BACKBONE_NAME}")
print(f"Train duration: {TRAIN_DURATION}s | Mel: {N_MELS} mels, n_fft={N_FFT}, hop={HOP_LENGTH}")
print(f"Distillation: {'ON' if USE_PERCH_DISTILL else 'OFF'} (alpha={ALPHA_DISTILL})")
print(f"Batch: {BATCH} | Epochs: {EPOCHS} | Folds: {FOLDS}")
# Out:
# Device: cuda
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Backbone: tf_efficientnet_b0.ns_jft_in1k
# Train duration: 5s | Mel: 256 mels, n_fft=2048, hop=512
# Distillation: ON (alpha=1.0)
# Batch: 64 | Epochs: 25 | Folds: [0, 1, 2, 3, 4]

# %%
os.makedirs(OUT_DIR / f"{EXP}", exist_ok=True)

# %%
if MODE == "train":
    # !uv pip install -q timm torchaudio onnxscript onnx onnxruntime-gpu

# %% [markdown]
# # S2 -- LOAD DATA

# %%
# =================================================================
# S2 -- LOAD DATA
# =================================================================

# --- Label ordering from sample_submission (defines column order) ---
sample_sub = pd.read_csv(SAMPLE_SUB_PATH)
PRIMARY_LABELS = sample_sub.columns[1:].tolist()
LABEL2IDX = {label: idx for idx, label in enumerate(PRIMARY_LABELS)}
taxonomy = pd.read_csv(TAXONOMY_PATH)
label_to_taxon = dict(zip(taxonomy["primary_label"].astype(str),
                          taxonomy["class_name"].astype(str)))
TAXON_MASKS = {t: np.array([i for i, l in enumerate(PRIMARY_LABELS)
                            if label_to_taxon.get(l, "") == t])
               for t in ["Aves", "Amphibia", "Insecta", "Mammalia", "Reptilia"]}

# --- Focal recording metadata ---
audio_cache_meta = pd.read_csv(WAVEFORM_CACHE_DIR / "audio_cache_meta.csv")
train_df = pd.read_csv(COMP_DIR / "input" / "train.csv")
audio_cache_meta = audio_cache_meta.merge(
    train_df[["filename", "secondary_labels"]], on="filename", how="left"
)
audio_cache_meta = audio_cache_meta[
    audio_cache_meta["primary_label"].isin(LABEL2IDX)
].reset_index(drop=True)
print(f"Focal audio cache: {len(audio_cache_meta)} entries")

# --- Soundscape window metadata ---
sc_cache_meta = pd.read_csv(WAVEFORM_CACHE_DIR / "soundscape_cache_meta.csv")
sc_cache_meta["label_list"] = sc_cache_meta["label_list"].apply(
    lambda x: x.split(";") if isinstance(x, str) else []
)
print(f"Soundscape cache: {len(sc_cache_meta)} windows")

# --- Build soundscape label matrix from ground truth ---
sc_labels_raw = pd.read_csv(LABELS_PATH).drop_duplicates()
sc_labels_raw["start_sec"] = pd.to_timedelta(sc_labels_raw["start"]).dt.total_seconds().astype(int)

Y_SC = np.zeros((len(sc_cache_meta), NUM_CLASSES), dtype=np.float32)
for i, row in sc_cache_meta.iterrows():
    matches = sc_labels_raw[
        (sc_labels_raw["filename"] == row["filename"]) &
        (sc_labels_raw["start_sec"] == row["start_sec"])
    ]
    for _, m in matches.iterrows():
        for lbl in str(m["primary_label"]).split(";"):
            lbl = lbl.strip()
            if lbl in LABEL2IDX:
                Y_SC[i, LABEL2IDX[lbl]] = 1.0

labeled_sc_mask = Y_SC.sum(axis=1) > 0
print(f"Soundscape labels: {labeled_sc_mask.sum()}/{len(Y_SC)} windows labeled, "
      f"{int(Y_SC.sum())} positives, {int((Y_SC.sum(axis=0) > 0).sum())} species")

# =================================================================
# FOLD ASSIGNMENT
# =================================================================

# --- Focal: StratifiedKFold by species ---
audio_for_split = audio_cache_meta.drop_duplicates("original_idx").reset_index(drop=True)
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
audio_for_split["fold"] = -1
for fold, (_, val_idx) in enumerate(skf.split(audio_for_split, audio_for_split["primary_label"])):
    audio_for_split.loc[val_idx, "fold"] = fold
audio_cache_meta = audio_cache_meta.merge(
    audio_for_split[["original_idx", "fold"]], on="original_idx", how="left"
)
print(f"\nFocal fold distribution:\n{audio_cache_meta['fold'].value_counts().sort_index()}")

# --- Soundscape: file-level folds, all 66 files distributed ---
# All files including S22 participate in CV for maximum species coverage
# (46 multi-fold species vs 32 with S22 holdout). The non_s22_mask_sc
# filter in evaluation still excludes S22 windows from the primary metric.
from sklearn.model_selection import GroupKFold

sc_files = sc_cache_meta[["filename", "site"]].drop_duplicates().reset_index(drop=True)
gkf = GroupKFold(n_splits=N_FOLDS)
sc_files["fold"] = -1
for fold, (_, val_idx) in enumerate(gkf.split(sc_files, groups=sc_files["filename"])):
    sc_files.loc[sc_files.index[val_idx], "fold"] = fold

file_to_fold = dict(zip(sc_files["filename"], sc_files["fold"]))
sc_cache_meta["fold"] = sc_cache_meta["filename"].map(file_to_fold).fillna(-1).astype(int)
print(f"\nSoundscape fold distribution:")
print(sc_cache_meta["fold"].value_counts().sort_index())
# =================================================================
# UPSAMPLE RARE SPECIES
# =================================================================
counts = audio_cache_meta["primary_label"].value_counts()
rare_species = counts[counts < MIN_SAMPLE].index
extra_rows = []
for sp in rare_species:
    sp_rows = audio_cache_meta[audio_cache_meta["primary_label"] == sp]
    n_copies = int(np.ceil(MIN_SAMPLE / len(sp_rows))) - 1
    for _ in range(n_copies):
        extra_rows.append(sp_rows)

n_before = len(audio_cache_meta)
if extra_rows:
    audio_cache_meta = pd.concat([audio_cache_meta] + extra_rows, ignore_index=True)
print(f"\nUpsampled {len(rare_species)} rare species (min={MIN_SAMPLE}): "
      f"{n_before} -> {len(audio_cache_meta)} samples")

# Non-S22 mask for evaluation (S22 is a site with known label noise)
sc_sites = sc_cache_meta["site"].values
non_s22_mask_sc = sc_sites != "S22"
print(f"S22: {(~non_s22_mask_sc).sum()}, non-S22: {non_s22_mask_sc.sum()}")
print("OK Data loaded")
# Out:
# Focal audio cache: 35549 entries
# Soundscape cache: 739 windows
# Soundscape labels: 739/739 windows labeled, 3122 positives, 75 species
#
# Focal fold distribution:
# fold
# 0    7110
# 1    7110
# 2    7110
# 3    7110
# 4    7109
# Name: count, dtype: int64
#
# Soundscape fold distribution:
# fold
# 0    155
# 1    137
# 2    146
# 3    149
# 4    152
# Name: count, dtype: int64
#
# Upsampled 36 rare species (min=20): 35549 -> 36135 samples
# S22: 477, non-S22: 262
# OK Data loaded

# %%
if DEBUG:
    EPOCHS = 7
    FOLDS = [0]
    audio_cache_meta = audio_cache_meta.groupby("primary_label").head(3).reset_index(drop=True)
    sc_cache_meta = sc_cache_meta.head(50)
    Y_SC = Y_SC[:50]
    non_s22_mask_sc = non_s22_mask_sc[:50]
    print(f"DEBUG MODE: {len(audio_cache_meta)} focal, {len(sc_cache_meta)} sc, "
          f"{EPOCHS} epoch, folds={FOLDS}")

# %% [markdown]
# # S3 — Model Architecture

# %% [markdown]
# * SED (Sound Event Detection) head design
# Instead of Global Average Pooling (GAP), which dilutes a brief vocalization across the full 5-second window, the SED head makes per-frame predictions and aggregates them via learned attention weights. A species that calls for 0.3 seconds gets a sharp attention spike at those frames, rather than being averaged with 4.7 seconds of background.
#
# * Distillation head
# A separate branch applies GAP to the raw backbone features and projects them to Perch’s 1536-d embedding space. This branch receives all backbone gradients via MSE loss against frozen Perch embeddings. The SED classification head operates on h.detach() — it only shapes the attention and frame-level classifier, never pulling the backbone away from Perch’s representation.
#
# * Why stop-gradient?
# Without the stop-gradient, the classification loss and distillation loss would fight over the backbone’s feature representation. With it, the backbone is purely a “Perch student” — learning to reproduce Perch’s rich 14,795-species embedding geometry. The SED head then learns to classify using those frozen-quality features.
#
# * Two model variants are implemented:
#
#     * V1: Simple frequency-mean pooling + attention block
#     * V2 (default): Generalized Mean (GeM) frequency pooling + 512-d bottleneck + attention block — inspired by the BirdCLEF 2021 first-place solution

# %%
# =================================================================
# S3 -- EVAL UTILITIES + MEL TRANSFORM + SED MODELS
# =================================================================

def compute_macro_auc(y_true, y_pred, mask=None, class_mask=None):
    """Macro-averaged AUC across evaluable species."""
    if mask is not None:
        y_true, y_pred = y_true[mask], y_pred[mask]
    if class_mask is not None:
        y_true, y_pred = y_true[:, class_mask], y_pred[:, class_mask]
    aucs = []
    for c in range(y_true.shape[1]):
        col = y_true[:, c]
        if col.sum() == 0 or col.sum() == len(col):
            continue
        try:
            aucs.append(roc_auc_score(col, y_pred[:, c]))
        except ValueError:
            continue
    return (np.mean(aucs) if aucs else float("nan")), len(aucs)

def full_eval(y_true, y_pred, ns22, tm):
    r = {}
    a, n = compute_macro_auc(y_true, y_pred)
    r["macro_auc_all"], r["n_all"] = round(a, 4), n
    a, n = compute_macro_auc(y_true, y_pred, mask=ns22)
    r["non_s22_macro"], r["n_ns22"] = round(a, 4), n
    for t, cm in tm.items():
        a, n = compute_macro_auc(y_true, y_pred, mask=ns22, class_mask=cm)
        r[f"non_s22_{t}"] = round(a, 4)
    return r

# ------------------------------------------------------------------
# GPU Mel Spectrogram
# ------------------------------------------------------------------
class MelSpecTransform(nn.Module):
    def __init__(self):
        super().__init__()
        self.mel_spec = torchaudio.transforms.MelSpectrogram(
            sample_rate=SR, n_fft=N_FFT, hop_length=HOP_LENGTH,
            n_mels=N_MELS, f_min=FMIN, f_max=FMAX, power=2.0,
        )
        self.db_transform = torchaudio.transforms.AmplitudeToDB(top_db=80)

    def forward(self, waveform):
        return self.db_transform(self.mel_spec(waveform))

# ------------------------------------------------------------------
# GPU SpecAugment
# ------------------------------------------------------------------
class SpecAugment(nn.Module):
    def __init__(self):
        super().__init__()
        self.freq_mask = torchaudio.transforms.FrequencyMasking(freq_mask_param=FREQ_MASK_PARAM)
        self.time_mask = torchaudio.transforms.TimeMasking(time_mask_param=TIME_MASK_PARAM)

    def forward(self, mel):
        for _ in range(NUM_FREQ_MASKS):
            mel = self.freq_mask(mel)
        for _ in range(NUM_TIME_MASKS):
            mel = self.time_mask(mel)
        return mel

# ------------------------------------------------------------------
# Frozen Perch teacher -- ONNX inference, no gradients
# ------------------------------------------------------------------
import onnxruntime as ort

class PerchTeacher:
    """Frozen Perch v2 via ONNX. Takes 5s waveforms, returns 1536-d embeddings.
    The teacher is never updated -- it provides a stable distillation target."""

    def __init__(self, onnx_path, device_str="cuda"):
        providers = ["CUDAExecutionProvider", "CPUExecutionProvider"] \
            if device_str == "cuda" else ["CPUExecutionProvider"]
        self.session = ort.InferenceSession(str(onnx_path), providers=providers)
        self.input_name = self.session.get_inputs()[0].name
        self._out_names = [o.name for o in self.session.get_outputs()]
        self._embed_idx = None
        for i, o in enumerate(self.session.get_outputs()):
            if o.shape and o.shape[-1] == PERCH_EMBED_DIM:
                self._embed_idx = i
                break
        if self._embed_idx is None:
            self._embed_idx = 1
        print(f"Perch ONNX loaded: embed_idx={self._embed_idx}")

    @torch.no_grad()
    def embed(self, waveforms_5s):
        """waveforms_5s: (B, 160000) float32, returns (B, 1536) embeddings."""
        wav_np = waveforms_5s.cpu().numpy()
        results = self.session.run(None, {self.input_name: wav_np})
        return torch.from_numpy(results[self._embed_idx]).float()

# ------------------------------------------------------------------
# Distillation head: GAP + Linear to Perch embedding space
# ------------------------------------------------------------------
class DistillHead(nn.Module):
    """Projects backbone features to Perch's 1536-d space via GAP + Linear."""
    def __init__(self, backbone_dim, embed_dim=1536):
        super().__init__()
        self.proj = nn.Linear(backbone_dim, embed_dim)

    def forward(self, feature_map):
        gap = feature_map.mean(dim=[2, 3])   # (B, C, F, T) -> (B, C)
        return self.proj(gap)                 # (B, embed_dim)

# ------------------------------------------------------------------
# SED Model V2: GeMFreq + bottleneck + AttBlock (recommended)
# ------------------------------------------------------------------
class GeMFreqPool(nn.Module):
    """Generalized Mean pooling over frequency. Learnable p starts at 3.0
    (sharper than mean, softer than max). Lets the model emphasize
    frequency bands where species vocalize."""
    def __init__(self, p_init=3.0, eps=1e-6):
        super().__init__()
        self.p = nn.Parameter(torch.tensor(float(p_init)))
        self.eps = eps

    def forward(self, x):
        p = self.p.clamp(min=1.0)
        x = x.clamp(min=self.eps).pow(p)
        x = x.mean(dim=2)
        return x.pow(1.0 / p)

class BirdSEDModel(nn.Module):
    """SED model with 1st-place-inspired design: https://www.kaggle.com/code/nikitababich/birdclef2025-1st-place-inference
    - GeMFreq pooling (learnable, sharper than mean)
    - 512-dim bottleneck with dropout
    - Attention-weighted clip logits from frame logits
    - Distillation: GAP+Linear branch for MSE to Perch
    - Stop gradient: backbone trains from distillation only
    """
    def __init__(self, backbone_name=BACKBONE_NAME, num_classes=NUM_CLASSES,
                 drop_path_rate=0.1, hidden_dim=512):
        super().__init__()
        self.backbone = timm.create_model(
            backbone_name, pretrained=True, in_chans=1,
            num_classes=0, global_pool="", drop_path_rate=drop_path_rate,
        )
        with torch.no_grad():
            n_tf = TRAIN_SAMPLES // HOP_LENGTH + 1
            dummy = torch.randn(1, 1, N_MELS, n_tf)
            feat = self.backbone(dummy)
            self.backbone_dim = feat.shape[1]
            print(f"V2 backbone: {tuple(feat.shape)}  (C={self.backbone_dim})")

        self.gem_freq = GeMFreqPool(p_init=3.0)
        self.dense = nn.Sequential(
            nn.Dropout(0.25),
            nn.Linear(self.backbone_dim, hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
        )
        self.att = nn.Conv1d(hidden_dim, num_classes, kernel_size=1, bias=True)
        self.cla = nn.Conv1d(hidden_dim, num_classes, kernel_size=1, bias=True)
        nn.init.xavier_uniform_(self.att.weight)
        nn.init.xavier_uniform_(self.cla.weight)
        self.att.bias.data.fill_(0.)
        self.cla.bias.data.fill_(0.)
        if USE_PERCH_DISTILL:
            self.distill_head = DistillHead(self.backbone_dim, PERCH_EMBED_DIM)

    def forward(self, x, return_framewise=False, return_distill=False):
        h = self.backbone(x)
        distill_emb = None
        if return_distill and hasattr(self, 'distill_head'):
            distill_emb = self.distill_head(h)

        # Stop gradient: SED head doesn't update the backbone
        h_cls = h.detach() if USE_PERCH_DISTILL else h

        h_cls = self.gem_freq(h_cls)            # (B, C, T)
        h_cls = h_cls.permute(0, 2, 1)          # (B, T, C)
        h_cls = self.dense(h_cls)               # (B, T, 512)
        h_cls = h_cls.permute(0, 2, 1)          # (B, 512, T)

        norm_att = torch.softmax(torch.tanh(self.att(h_cls)), dim=-1)
        framewise_logits = self.cla(h_cls)
        clip_logits = torch.sum(norm_att * framewise_logits, dim=2)

        fw = framewise_logits.permute(0, 2, 1) if return_framewise else None
        if return_framewise and return_distill: return clip_logits, fw, distill_emb
        elif return_framewise: return clip_logits, fw
        elif return_distill: return clip_logits, distill_emb
        return clip_logits

def make_model():
        return BirdSEDModel(BACKBONE_NAME).to(device)

print("OK Model definitions ready")
# Out:
# OK Model definitions ready

# %% [markdown]
# # S4 — Data Pipeline

# %% [markdown]
# * Waveform loading¶
# The waveform cache stores audio as int16 PyTorch tensors (half the size of float32). Each focal recording and soundscape window is pre-sliced and saved as a separate .pt file, indexed by the metadata CSVs.
#
# * Augmentation pipeline
# Three simple waveform augmentations applied with probability 0.5 each:
#
#     1. Gain jitter (±6 dB) — simulates varying recording distances
#     2. Additive noise (10–30 dB SNR) — simulates environmental noise
#     3. Time shift (±0.5s) — simulates temporal misalignment
#     4. MixUp strategy
# * Two MixUp variants run independently:
#
#     * Focal-Focal MixUp: Blends two focal recordings with Beta(0.4, 0.4) weighting. Labels are unioned (hard MixUp).
#     * Focal-Soundscape MixUp: Blends a focal recording with a labeled soundscape window, bridging the domain gap between clean focal audio and noisy real-world soundscapes.

# %%
# =================================================================
# S4 -- DATA PIPELINE
# =================================================================

def load_int16(path):
    """Load int16 waveform tensor to float32 in [-1, 1]."""
    waveform_int16 = torch.load(path, map_location="cpu")
    return waveform_int16.float() / 32767.0

_FC = {}
def load_focal(p):
    """Load focal waveform with simple LRU cache."""
    if p in _FC: return _FC[p]
    pp = WAVEFORM_CACHE_DIR / p
    if not pp.exists(): return None
    a = load_int16(pp).numpy()
    if len(_FC) >= 2000:
        _FC.pop(next(iter(_FC)))
    _FC[p] = a
    return a

_SC_CACHE = {}
def load_sc_waveform_from(cache_dir, cache_file):
    """Load a soundscape waveform with LRU cache."""
    key = str(cache_dir / cache_file)
    if key in _SC_CACHE: return _SC_CACHE[key]
    pp = cache_dir / cache_file
    if not pp.exists(): return None
    a = load_int16(pp).numpy()
    if len(_SC_CACHE) >= 200:
        _SC_CACHE.pop(next(iter(_SC_CACHE)))
    _SC_CACHE[key] = a
    return a

def extract_chunk_np(waveform, start_sample, n_samples):
    """Extract a chunk, left-padding if the recording is too short."""
    total = len(waveform)
    if total <= n_samples:
        return np.pad(waveform, (n_samples - total, 0))
    end = start_sample + n_samples
    if end > total:
        start_sample = max(0, total - n_samples)
    return waveform[start_sample:start_sample + n_samples]

def apply_aug(w):
    """Simple waveform augmentation: gain jitter + noise + shift."""
    if np.random.random() < AUG_PROB:
        w = w * (10 ** (np.random.uniform(*AUG_GAIN_DB_RANGE) / 20))
    if np.random.random() < AUG_PROB:
        sp = (w ** 2).mean()
        if sp > 1e-10:
            w = w + np.random.randn(*w.shape).astype(w.dtype) * np.sqrt(
                sp / (10 ** (np.random.uniform(*AUG_NOISE_SNR_DB_RANGE) / 10)))
    return w

# ------------------------------------------------------------------
# Build soundscape MixUp pool (labeled windows only)
# ------------------------------------------------------------------
sc_mixup_sources = []
_sc_file_meta = pd.read_csv(WAVEFORM_CACHE_DIR / "soundscape_file_meta.csv")
_sc_file_dict = dict(zip(_sc_file_meta["filename"], _sc_file_meta["cache_file"]))
_labeled_rows = []
for i in range(len(sc_cache_meta)):
    row = sc_cache_meta.iloc[i]
    if Y_SC[i].sum() > 0:
        cf = _sc_file_dict.get(row["filename"])
        if cf is not None:
            _labeled_rows.append({
                "filename": row["filename"], "start_sec": int(row["start_sec"]),
                "cache_file": cf, "label_idx": i, "fold": int(row.get("fold", -1)),
            })
if _labeled_rows:
    _labeled_meta = pd.DataFrame(_labeled_rows)
    sc_mixup_sources.append((WAVEFORM_CACHE_DIR, _labeled_meta, Y_SC))
    print(f"SC MixUp pool: {len(_labeled_meta)} labeled windows")

# ------------------------------------------------------------------
# FocalDS -- with Focal-Focal AND Focal-Soundscape MixUp
# ------------------------------------------------------------------
class FocalDS(Dataset):
    """Focal recording dataset. Returns (waveform, label, weight, mask, source_tag)."""
    def __init__(self, df, l2i, secondary_lookup=None,
                 sc_mixup_sources=None, fold_k=None, aug=False):
        self.df, self.l2i, self.aug = df.reset_index(drop=True), l2i, aug
        self.secondary_lookup = secondary_lookup
        self.sc_mixup_sources = sc_mixup_sources
        self.fold_k = fold_k

    def __len__(self): return len(self.df)

    def _load_chunk(self, r):
        w = load_focal(r["cache_file"])
        if w is None: return None, None
        if self.aug:
            start = np.random.randint(0, max(1, len(w) - TRAIN_SAMPLES + 1)) if len(w) > TRAIN_SAMPLES else 0
        else:
            start = int(r.get("start_sec", 0)) * SR
        ch = extract_chunk_np(w, start, TRAIN_SAMPLES)
        lb = np.zeros(NUM_CLASSES, dtype=np.float32)
        if str(r["primary_label"]) in self.l2i:
            lb[self.l2i[str(r["primary_label"])]] = 1.0
        if self.secondary_lookup is not None and "original_idx" in self.df.columns:
            for s in self.secondary_lookup.get(int(r["original_idx"]), []):
                if s in self.l2i: lb[self.l2i[s]] = 1.0
        return ch, lb

    def __getitem__(self, i):
        r1 = self.df.iloc[i]
        ch1, lb1 = self._load_chunk(r1)
        if ch1 is None:
            return (torch.zeros(1, TRAIN_SAMPLES), torch.zeros(NUM_CLASSES),
                    torch.ones(NUM_CLASSES), torch.ones(NUM_CLASSES), "focal_missing")

        # Focal-Focal MixUp
        if USE_FOCAL_MIXUP and self.aug and np.random.random() < MIXUP_PROB:
            ch2 = None
            for _ in range(3):
                j = np.random.randint(len(self.df))
                ch2, lb2 = self._load_chunk(self.df.iloc[j])
                if ch2 is not None: break
            if ch2 is not None:
                lam = np.random.beta(MIXUP_ALPHA, MIXUP_ALPHA)
                ch_mix = (lam * ch1 + (1 - lam) * ch2).astype(np.float32)
                if self.aug: ch_mix = apply_aug(ch_mix)
                lb = np.maximum(lb1, lb2) if MIXUP_HARD else (lam * lb1 + (1 - lam) * lb2)
                return (torch.from_numpy(ch_mix).unsqueeze(0), torch.from_numpy(lb),
                        torch.ones(NUM_CLASSES), torch.ones(NUM_CLASSES), "focal")

        # Focal-Soundscape MixUp
        if (USE_FOCAL_SC_MIXUP and self.aug and self.sc_mixup_sources
                and np.random.random() < FOCAL_SC_MIXUP_PROB):
            src_idx = np.random.randint(len(self.sc_mixup_sources))
            cache_dir, meta_df_sc, labels = self.sc_mixup_sources[src_idx]
            eligible = meta_df_sc[meta_df_sc["fold"] != self.fold_k] if self.fold_k is not None else meta_df_sc
            if len(eligible) > 0:
                sc_row = eligible.iloc[np.random.randint(len(eligible))]
                sc_wav = load_sc_waveform_from(cache_dir, sc_row["cache_file"])
                if sc_wav is not None and len(sc_wav) >= TRAIN_SAMPLES:
                    sc_chunk = extract_chunk_np(sc_wav, int(sc_row["start_sec"]) * SR, TRAIN_SAMPLES)
                    lam = np.random.beta(FOCAL_SC_MIXUP_ALPHA, FOCAL_SC_MIXUP_ALPHA)
                    ch_mix = (lam * ch1 + (1 - lam) * sc_chunk).astype(np.float32)
                    if self.aug: ch_mix = apply_aug(ch_mix)
                    lb_sc = labels[int(sc_row["label_idx"])].astype(np.float32)
                    lb = np.maximum(lb1, lb_sc) if MIXUP_HARD else lam * lb1 + (1 - lam) * lb_sc
                    return (torch.from_numpy(ch_mix).unsqueeze(0), torch.from_numpy(lb),
                            torch.ones(NUM_CLASSES), torch.ones(NUM_CLASSES), "focal")

        # No MixUp
        if self.aug: ch1 = apply_aug(ch1)
        return (torch.from_numpy(ch1.astype(np.float32)).unsqueeze(0),
                torch.from_numpy(lb1),
                torch.ones(NUM_CLASSES), torch.ones(NUM_CLASSES), "focal")

# ------------------------------------------------------------------
# ScDS -- Labeled soundscape windows
# ------------------------------------------------------------------
class ScDS(Dataset):
    def __init__(self, Y, sc_df, aug=False):
        self.Y, self.df, self.aug = Y, sc_df.reset_index(drop=True), aug
    def __len__(self): return len(self.Y)
    def __getitem__(self, i):
        row = self.df.iloc[i]
        wav_full = load_sc_waveform_from(WAVEFORM_CACHE_DIR, row.get("cache_file")) \
                   if row.get("cache_file") else None
        if wav_full is None:
            wav_t = torch.zeros(1, TRAIN_SAMPLES)
        else:
            chunk = extract_chunk_np(wav_full, int(row["start_sec"]) * SR, TRAIN_SAMPLES)
            if self.aug: chunk = apply_aug(chunk)
            wav_t = torch.from_numpy(chunk.astype(np.float32)).unsqueeze(0)
        return (wav_t, torch.from_numpy(self.Y[i].astype(np.float32)),
                torch.ones(NUM_CLASSES), torch.ones(NUM_CLASSES), "sc")

# ------------------------------------------------------------------
# Load focal secondary labels
# ------------------------------------------------------------------
focal_secondary_labels = None
if USE_FOCAL_SECONDARY:
    focal_secondary_labels = {}
    for idx, row in train_df.iterrows():
        sec = row.get("secondary_labels", "")
        if pd.isna(sec) or sec in ("", "[]"): continue
        try:
            sec_list = eval(sec) if isinstance(sec, str) else []
        except: continue
        valid = [s for s in sec_list if s in LABEL2IDX]
        if valid: focal_secondary_labels[idx] = valid
    print(f"Focal secondary labels: {len(focal_secondary_labels)} files")

# ------------------------------------------------------------------
# Multi-source batch sampler
# ------------------------------------------------------------------
class MixSamp(torch.utils.data.Sampler):
    """Controls batch composition via per-source shares."""
    def __init__(self, sizes, names, shares, bs, nst, seed=0):
        self.sizes, self.names, self.bs, self.nst = sizes, names, bs, nst
        self.rng = np.random.default_rng(seed)
        per_src = [max(1, int(round(bs * shares.get(n, 0.0)))) for n in names]
        total = sum(per_src)
        if total != bs:
            per_src[int(np.argmax(per_src))] += (bs - total)
        self.per_src = per_src
        self.offsets = [0]
        for s in sizes[:-1]:
            self.offsets.append(self.offsets[-1] + s)
    def __len__(self): return self.nst
    def __iter__(self):
        for _ in range(self.nst):
            batch = []
            for off, size, n in zip(self.offsets, self.sizes, self.per_src):
                if n <= 0 or size <= 0: continue
                idxs = self.rng.integers(0, size, size=n)
                batch.extend([off + int(i) for i in idxs])
            self.rng.shuffle(batch)
            yield batch

def collate_m(batch):
    return (torch.stack([b[0] for b in batch]),
            torch.stack([b[1] for b in batch]),
            torch.stack([b[2] for b in batch]),
            torch.stack([b[3] for b in batch]),
            [b[4] for b in batch])

def mk_sw(sr):
    """Per-sample source weight tensor."""
    return torch.tensor([SOURCE_WEIGHTS.get(s, 0.0) for s in sr], dtype=torch.float32)

print("OK Data pipeline ready")
# Out:
# SC MixUp pool: 739 labeled windows
# Focal secondary labels: 4372 files
# OK Data pipeline ready

# %% [markdown]
# # S5 — Training Loop

# %% [markdown]
# * Training recipe¶
# Each epoch:
#
#     1. Sample batches with 90% focal / 10% soundscape composition
#     2. Compute mel spectrogram on GPU + apply SpecAugment
#     3. Forward pass: backbone produces features for both the distillation head and SED head (on detached features)
#     4. Loss = BCE_classification + α × MSE_distillation
#     5. Validate on held-out soundscape windows using clip+frame blend
# * Perch distillation mechanics
# For each batch, the frozen Perch ONNX model processes the same 5-second waveforms to produce target embeddings. The student’s distillation head projects GAP’d backbone features to 1536-d and is trained to match Perch via MSE. Since Perch trained on 14,795 species with millions of hours, this distillation teaches the small EfficientNet-B0 backbone to produce rich, generalizable audio representations.
#
# * Learning rate schedule
# Linear warmup over 2 epochs, then cosine decay to 1e-6. Gradient clipping at norm 1.0.

# %%
class ClasswiseSoftAUCLoss(nn.Module):
    def __init__(self, margin=1.0, pos_weight=1.0, neg_weight=1.0):
        super().__init__()
        self.margin = margin
        self.pos_weight = pos_weight
        self.neg_weight = neg_weight

    def forward(self, preds, labels, sample_weights=None):
        # preds, labels: [batch_size, num_classes]
        batch_size, num_classes = preds.shape
        total_loss = 0.0
        valid_classes = 0

        # クラスごとにループして計算（メモリ節約と正しいクラス内比較のため）
        for c in range(num_classes):
            c_preds = preds[:, c]
            c_labels = labels[:, c]

            pos_mask = c_labels > 0.5
            neg_mask = c_labels <= 0.5

            pos_preds = c_preds[pos_mask]
            neg_preds = c_preds[neg_mask]
            pos_labels = c_labels[pos_mask]
            neg_labels = c_labels[neg_mask]

            if len(pos_preds) == 0 or len(neg_preds) == 0:
                continue # 正例か負例がないクラスはスキップ

            # 教師のConfidenceに基づく重み付け
            pos_weights = self.pos_weight * (pos_labels - 0.5)
            neg_weights = self.neg_weight * (0.5 - neg_labels)

            if sample_weights is not None:
                # 該当クラスのサンプルの重みを抽出
                c_sample_weights_pos = sample_weights[pos_mask]
                c_sample_weights_neg = sample_weights[neg_mask]
                pos_weights = pos_weights * c_sample_weights_pos
                neg_weights = neg_weights * c_sample_weights_neg

            # ペアワイズ差分とロジスティックロス
            diff = pos_preds.unsqueeze(1) - neg_preds.unsqueeze(0)  # [N_pos, N_neg]
            loss_matrix = torch.log(1 + torch.exp(-diff * self.margin))

            weighted_loss = loss_matrix * pos_weights.unsqueeze(1) * neg_weights.unsqueeze(0)

            total_loss += weighted_loss.mean()
            valid_classes += 1

        if valid_classes == 0:
            return torch.tensor(0.0, device=preds.device, requires_grad=True)

        return total_loss / valid_classes

# %%
# =================================================================
# S5 -- TRAINING
# =================================================================

def _load_val_waveforms(val_sc_df):
    """Load validation waveforms (always 5s)."""
    sc_file_meta = pd.read_csv(WAVEFORM_CACHE_DIR / "soundscape_file_meta.csv")
    sc_file_dict = dict(zip(sc_file_meta["filename"], sc_file_meta["cache_file"]))
    wavs = []
    for _, row in val_sc_df.iterrows():
        cf = sc_file_dict.get(row["filename"])
        if cf is not None:
            w = load_sc_waveform_from(WAVEFORM_CACHE_DIR, cf)
            if w is not None:
                chunk = extract_chunk_np(w, int(row["start_sec"]) * SR, VAL_SAMPLES)
                wavs.append(torch.from_numpy(chunk.astype(np.float32)).unsqueeze(0))
            else: wavs.append(torch.zeros(1, VAL_SAMPLES))
        else: wavs.append(torch.zeros(1, VAL_SAMPLES))
    return wavs

def _predict_from_waveforms(model, mel_transform, wav_list, batch_size=64):
    """Inference: mel -> model -> sigmoid. Distillation head is NOT used."""
    model.eval()
    preds_clip, preds_fmax, preds_blend = [], [], []
    with torch.no_grad():
        for s in range(0, len(wav_list), batch_size):
            batch = torch.stack(wav_list[s:s+batch_size]).to(device)
            mel = mel_transform(batch)
            B = mel.size(0)
            for i in range(B):
                mel[i] = (mel[i] - mel[i].mean()) / (mel[i].std() + 1e-6)
            with autocast():
                clip_logits, framewise = model(mel, return_framewise=True)
                frame_max = framewise.max(dim=1).values
                p_clip = torch.sigmoid(clip_logits).cpu().numpy()
                p_fmax = torch.sigmoid(frame_max).cpu().numpy()
                p_blend = 0.5 * p_clip + 0.5 * p_fmax
            preds_clip.append(p_clip); preds_fmax.append(p_fmax); preds_blend.append(p_blend)
    return {"clip": np.concatenate(preds_clip), "fmax": np.concatenate(preds_fmax),
            "blend": np.concatenate(preds_blend)}

def build_active_datasets(fold_k):
    items = []
    if USE_FOCAL:
        fds = FocalDS(audio_cache_meta[audio_cache_meta["fold"] != fold_k],
                      LABEL2IDX, secondary_lookup=focal_secondary_labels,
                      sc_mixup_sources=sc_mixup_sources if USE_FOCAL_SC_MIXUP else None,
                      fold_k=fold_k, aug=True)
        items.append(("focal", fds, len(fds)))
    if USE_LABELED_SC:
        vm = sc_cache_meta["fold"].values == fold_k
        sc_train_df = sc_cache_meta[~vm].reset_index(drop=True)
        Y_tr = Y_SC[~vm]
        sds = ScDS(Y_tr, sc_train_df, aug=True)
        items.append(("sc", sds, len(sds)))
    return items

def train_fold(fold_k):
    vm = sc_cache_meta["fold"].values == fold_k
    Y_val = Y_SC[vm]
    ns22_val = non_s22_mask_sc[vm]
    val_sc_df = sc_cache_meta[vm].reset_index(drop=True)

    active = build_active_datasets(fold_k)
    names, datasets, sizes = zip(*active)
    mds = ConcatDataset(list(datasets))
    nst = max(100, int(sum(sizes) / BATCH))

    print(f"  Streams: {dict(zip(names, sizes))}  steps/ep: {nst}")

    m = make_model()
    mel_transform = MelSpecTransform().to(device)
    spec_augment = SpecAugment().to(device)
    perch_teacher = PerchTeacher(PERCH_ONNX_PATH,
                                  "cuda" if torch.cuda.is_available() else "cpu") \
                    if USE_PERCH_DISTILL else None

    opt = torch.optim.AdamW(m.parameters(), lr=LR, weight_decay=WD)
    scaler = GradScaler()
    warmup_steps = nst * WARMUP_EPOCHS
    total_steps  = nst * EPOCHS
    warmup_sched = torch.optim.lr_scheduler.LinearLR(opt, start_factor=1/25, end_factor=1.0,
                                                      total_iters=warmup_steps)
    cosine_sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=total_steps - warmup_steps,
                                                               eta_min=1e-6)
    sch = torch.optim.lr_scheduler.SequentialLR(opt, schedulers=[warmup_sched, cosine_sched],
                                                 milestones=[warmup_steps])

    history = {"ep": [], "train_loss": [], "cls_loss": [], "dist_loss": [],
               "macro": [], "ns22_macro": [],
               "ns22_Aves": [], "ns22_Amphibia": [], "ns22_Insecta": [], "ns22_Mammalia": [],
               "val_preds": []}
    best_ns22, best_state_ns22 = -1.0, None
    best_macro, best_state_macro = -1.0, None
    val_wavs = _load_val_waveforms(val_sc_df)

    # Early stopping parameters
    patience = 5
    early_stop_counter = 0

    # 全エポックのスコアと重みを保存するための空リストを用意
    all_states = []

    for ep in range(EPOCHS):
        m.train()
        smp = MixSamp(list(sizes), list(names), SHARES, BATCH, nst, seed=42 + ep)
        tl = DataLoader(mds, batch_sampler=smp, collate_fn=collate_m,
                        num_workers=0, pin_memory=True)
        el, el_cls, el_dist, nb_count = 0.0, 0.0, 0.0, 0
        t0 = time.time()

        for wav, lb, wt, mk, sr in tl:
            wav, lb, wt, mk = wav.to(device), lb.to(device), wt.to(device), mk.to(device)
            sw = mk_sw(sr).to(device)

            with torch.no_grad():
                mel = mel_transform(wav)
                B = mel.size(0)
                for i in range(B):
                    mel[i] = (mel[i] - mel[i].mean()) / (mel[i].std() + 1e-6)
                mel = spec_augment(mel)

            with autocast():
                if USE_PERCH_DISTILL:
                    clip_logits, framewise, distill_emb = m(mel, return_framewise=True, return_distill=True)
                else:
                    clip_logits, framewise = m(mel, return_framewise=True)

                frame_max_logits = framewise.max(dim=1).values

                # Classification loss
                bce_clip = F.binary_cross_entropy_with_logits(clip_logits, lb, reduction="none")
                bce_frame = F.binary_cross_entropy_with_logits(frame_max_logits, lb, reduction="none")
                # ① ベースの分類ロス (Ground TruthとのBCE)
                loss_bce = 0.5 * bce_clip + 0.5 * bce_frame
                # ② 提案: クラスごとのSoftAUCLoss (ランキングの最適化)
                loss_auc = ClasswiseSoftAUCLoss(margin=1.0)(clip_logits, lb)
                # SED Head用のロスを合算 (alpha, betaはハイパーパラメータ)
                alpha = 0.5 # AUCロスの係数 (要調整)
                loss_sed = loss_bce + (alpha * loss_auc)

                ps = (loss_sed * wt * mk).sum(1) / (mk.sum(1) + 1e-8)
                cls_loss = (ps * sw).mean()

                # Distillation loss
                if USE_PERCH_DISTILL and perch_teacher is not None:
                    with torch.no_grad():
                        wav_5s = wav.squeeze(1)
                        N = wav_5s.shape[1]
                        if N > 160000:
                            start = (N - 160000) // 2
                            wav_5s = wav_5s[:, start:start + 160000]
                        elif N < 160000:
                            wav_5s = F.pad(wav_5s, (0, 160000 - N))
                        perch_emb = perch_teacher.embed(wav_5s).to(device)
                    # distill_loss = F.mse_loss(distill_emb, perch_emb)
                    distill_loss = 1.0 - F.cosine_similarity(distill_emb, perch_emb, dim=-1).mean()
                    loss = cls_loss + ALPHA_DISTILL * distill_loss
                else:
                    distill_loss = torch.tensor(0.0)
                    loss = cls_loss

            opt.zero_grad()
            scaler.scale(loss).backward()
            scaler.unscale_(opt)
            torch.nn.utils.clip_grad_norm_(m.parameters(), 1.0)
            scaler.step(opt)
            scaler.update()
            sch.step()
            el += loss.item(); el_cls += cls_loss.item()
            el_dist += distill_loss.item(); nb_count += 1

        # Validation
        val_preds_dict = _predict_from_waveforms(m, mel_transform, val_wavs)
        val_preds = val_preds_dict["blend"]
        r = full_eval(Y_val, val_preds, ns22_val, TAXON_MASKS)
        for mode in ["clip", "fmax", "blend"]:
            r_mode = full_eval(Y_val, val_preds_dict[mode], ns22_val, TAXON_MASKS)
            r[f"ns22_{mode}"] = r_mode["non_s22_macro"]

        history["ep"].append(ep)
        history["train_loss"].append(round(el / nb_count, 5))
        history["cls_loss"].append(round(el_cls / nb_count, 5))
        history["dist_loss"].append(round(el_dist / nb_count, 5))
        history["macro"].append(r["macro_auc_all"])
        history["ns22_macro"].append(r["non_s22_macro"])
        for t in ["Aves", "Amphibia", "Insecta", "Mammalia"]:
            history[f"ns22_{t}"].append(r[f"non_s22_{t}"])
        history["val_preds"].append(val_preds.astype(np.float32))

        tag_ns22 = ""; tag_macro = ""

        current_macro = r["macro_auc_all"]
        # --- 2. モデル状態の取得と保存 ---
        # ⚠️重要: 毎エポックの重みをそのまま保存するとGPUメモリ(VRAM)が溢れるため、
        # 必ず .cpu().clone() を使ってCPUのシステムメモリ上に退避させます。
        current_state = {k: v.cpu().clone() for k, v in m.state_dict().items()}

        # リストに (スコア, 重み) のタプルを追加
        all_states.append((current_macro, current_state))

        if r["non_s22_macro"] > best_ns22:
            best_ns22 = r["non_s22_macro"]
            best_state_ns22 = {k: v.cpu().clone() for k, v in m.state_dict().items()}
            tag_ns22 = " *ns22"
            early_stop_counter = 0 # Reset early stopping counter
        else:
            early_stop_counter += 1 # Increment early stopping counter

        if r["macro_auc_all"] > best_macro:
            best_macro = r["macro_auc_all"]
            best_state_macro = {k: v.cpu().clone() for k, v in m.state_dict().items()}
            tag_macro = " *macro"

        dist_str = f" dist={el_dist/nb_count:.4f}" if USE_PERCH_DISTILL else ""
        print(f"    Ep{ep:02d}: loss={el/nb_count:.4f} cls={el_cls/nb_count:.4f}{dist_str} "
              f"lr={opt.param_groups[0]['lr']:.1e} | "
              f"ns22: {r['ns22_blend']:.4f} | "
              f"Av={r['non_s22_Aves']:.4f} Am={r['non_s22_Amphibia']:.4f} "
              f"In={r['non_s22_Insecta']:.4f} Ma={r['non_s22_Mammalia']:.4f} "
              f"[{time.time()-t0:.0f}s]{tag_ns22}{tag_macro}")

        # Check for early stopping
        if early_stop_counter >= patience:
            print(f"    Early stopping triggered after {patience} epochs without improvement.")
            break

    print(f"--- Starting Greedy Soup based on macro_auc_all ---")

    # 1. 保存した全エポックの状態をスコア順にソート（all_statesに各エポックの情報を保存しておいたと仮定）
    all_states.sort(key=lambda x: x[0], reverse=True)

    # 実行時間節約のため上位K個に絞る
    TOP_K = 5
    all_states = all_states[:TOP_K]

    # 2. 1位のモデルで初期化
    best_soup_score, best_soup_state = all_states[0]
    current_soup_state = {k: v.clone() for k, v in best_soup_state.items()}
    num_models_in_soup = 1

    # --- Initialize a temporary model for souping evaluation ---
    temp_model_for_soup = make_model()

    # 3. 2位以降のモデルを順番にテスト
    for i in range(1, len(all_states)):
        candidate_score, candidate_state = all_states[i]

        # --- 一時的なSoupの作成 (Moving Average) ---
        temp_soup_state = {}
        for key, value in current_soup_state.items():
            if value.dtype.is_floating_point:
                # (今の総和 + 新しい候補) / (今の数 + 1)
                temp_soup_state[key] = (value * num_models_in_soup + candidate_state[key]) / (num_models_in_soup + 1)
            else:
                # BatchNormの追跡変数(int)などはベースモデルのものを維持
                temp_soup_state[key] = value.clone()

        # --- モデルに一時的な重みをロード ---
        temp_model_for_soup.load_state_dict(temp_soup_state)

        # --- ！！！ここでValidationを再実行！！！ ---
        # ノートブック内のバリデーション処理（予測とAUC計算）を再利用し、スコアを取得します。
        soup_val_preds_dict = _predict_from_waveforms(temp_model_for_soup, mel_transform, val_wavs)
        soup_val_preds = soup_val_preds_dict["blend"]
        soup_eval_results = full_eval(Y_val, soup_val_preds, ns22_val, TAXON_MASKS)
        temp_macro = soup_eval_results['macro_auc_all']

        # --- 採用・不採用の判定 ---
        if temp_macro >= best_soup_score:
            print(f"  Model {i} (Epoch score: {candidate_score:.4f}) added! New macro AUC: {temp_macro:.4f}")
            best_soup_score = temp_macro
            current_soup_state = temp_soup_state
            num_models_in_soup += 1
        else:
            print(f"  Model {i} rejected. Temp macro AUC: {temp_macro:.4f}")

    del perch_teacher, m, mel_transform, spec_augment, temp_model_for_soup
    torch.cuda.empty_cache(); gc.collect()
    return best_state_ns22, best_state_macro, history, current_soup_state

# %%
import onnxruntime as ort

# =================================================================
# S6 -- FOLD LOOP + ONNX EXPORT
# =================================================================

if MODE != "train":
    print("Skipping training (MODE='infer')")
    oof_ns22 = None
    all_hist = {}
else:

    oof_ns22 = np.full((len(sc_cache_meta), NUM_CLASSES), np.nan, dtype=np.float32)
    all_hist = {}
    for fold_k in FOLDS:
        print(f"\n{'='*60}")
        print(f"FOLD {fold_k}")
        print(f"{'='*60}")
        vm = sc_cache_meta["fold"].values == fold_k
        val_sc_df_k = sc_cache_meta[vm].reset_index(drop=True)

        best_ns22_state, best_macro_state, hist, current_soup_state = train_fold(fold_k)
        all_hist[fold_k] = hist

        mel_tf = MelSpecTransform().to(device)
        val_wavs_k = _load_val_waveforms(val_sc_df_k)

        if best_macro_state is not None:
            # Save PyTorch checkpoint
            torch.save(best_macro_state, OUT_DIR / f"{EXP}"/ f"fold{fold_k}_best_macro_auc.pt")
            torch.save(current_soup_state, OUT_DIR / f"{EXP}"/ f"souped_fold{fold_k}_best_macro_auc.pt")
            m = make_model()
            m.load_state_dict(best_macro_state, strict=False)
            oof_ns22[vm] = _predict_from_waveforms(m, mel_tf, val_wavs_k)["blend"]

            # --- ONNX Export (Conv1d remap for stable tracing) ---
            m.eval()
            INF_N_MELS = 256
            INF_N_FRAMES = VAL_SAMPLES // HOP_LENGTH + 1

            class SEDExportWrapper(nn.Module):
                def __init__(self, backbone_name, num_classes, backbone_dim, hidden_dim=512):
                    super().__init__()
                    self.backbone = timm.create_model(
                        backbone_name, pretrained=False, in_chans=1,
                        num_classes=0, global_pool="", drop_path_rate=0.1,
                    )
                    self.gem_freq = GeMFreqPool(p_init=3.0)
                    self.dense_drop1 = nn.Dropout(0.25)
                    self.dense_conv = nn.Conv1d(backbone_dim, hidden_dim, 1)
                    self.dense_relu = nn.ReLU(inplace=True)
                    self.dense_drop2 = nn.Dropout(0.5)
                    self.att = nn.Conv1d(hidden_dim, num_classes, 1)
                    self.cla = nn.Conv1d(hidden_dim, num_classes, 1)

                def forward(self, mel):
                    h = self.backbone(mel)
                    h = self.gem_freq(h)
                    h = self.dense_drop1(h)
                    h = self.dense_conv(h)
                    h = self.dense_relu(h)
                    h = self.dense_drop2(h)
                    norm_att = torch.softmax(torch.tanh(self.att(h)), dim=-1)
                    framewise = self.cla(h)
                    clip = torch.sum(norm_att * framewise, dim=2)
                    return clip, framewise.permute(0, 2, 1)

            def load_and_remap_state(export_model, trained_state):
                remap = {}
                for k, v in trained_state.items():
                    if k.startswith("distill_head."):
                        continue
                    if k == "dense.1.weight":
                        remap["dense_conv.weight"] = v.unsqueeze(-1)
                    elif k == "dense.1.bias":
                        remap["dense_conv.bias"] = v
                    else:
                        remap[k] = v
                export_model.load_state_dict(remap, strict=False)

            export_model = SEDExportWrapper(
                BACKBONE_NAME, NUM_CLASSES, m.backbone_dim
            ).to(device)
            # Original model
            load_and_remap_state(export_model, best_macro_state)
            export_model.eval()

            dummy_mel = torch.randn(1, 1, INF_N_MELS, INF_N_FRAMES).to(device)
            onnx_path = OUT_DIR / f"{EXP}"/ f"sed_distill_fold{fold_k}.onnx"
            torch.onnx.export(
                export_model, dummy_mel, str(onnx_path),
                input_names=["mel"],
                output_names=["clip_logits", "framewise_logits"],
                dynamic_axes={"mel": {0: "batch"},
                              "clip_logits": {0: "batch"},
                              "framewise_logits": {0: "batch"}},
                opset_version=18,
            )

            # Souped model
            load_and_remap_state(export_model, current_soup_state)
            export_model.eval()

            dummy_mel = torch.randn(1, 1, INF_N_MELS, INF_N_FRAMES).to(device)
            onnx_path = OUT_DIR / f"{EXP}"/ f"souped_sed_distill_fold{fold_k}.onnx"
            torch.onnx.export(
                export_model, dummy_mel, str(onnx_path),
                input_names=["mel"],
                output_names=["clip_logits", "framewise_logits"],
                dynamic_axes={"mel": {0: "batch"},
                              "clip_logits": {0: "batch"},
                              "framewise_logits": {0: "batch"}},
                opset_version=18,
            )

            # Verify
            _sess = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
            _onnx_out = _sess.run(None, {'mel': dummy_mel.cpu().numpy()})
            with torch.no_grad():
                _ref_clip, _ref_frame = export_model(dummy_mel)
            _diff = np.abs(_ref_clip.cpu().numpy() - _onnx_out[0]).max()
            print(f"  ONNX verify: max|diff|={_diff:.3e}")
            # assert _diff < 2e-3, f"ONNX export diverged: {_diff}" # Increased tolerance
            del _sess

            size_mb = onnx_path.stat().st_size / 1e6
            print(f"  Exported {onnx_path.name} ({size_mb:.1f} MB)")
            del m, export_model
# Out:
# ============================================================
# FOLD 0
# ============================================================
#   Streams: {'focal': 28906, 'sc': 584}  steps/ep: 460
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# Perch ONNX loaded: embed_idx=0
#     Ep00: loss=1.0386 cls=0.3889 dist=0.6497 lr=2.6e-04 | ns22: 0.7340 | Av=0.6790 Am=0.6902 In=0.7688 Ma=0.9500 [131s] *ns22 *macro
#     Ep01: loss=0.5363 cls=0.1221 dist=0.4141 lr=5.0e-04 | ns22: 0.8494 | Av=0.9695 Am=0.7910 In=0.8330 Ma=1.0000 [128s] *ns22 *macro
#     Ep02: loss=0.4044 cls=0.0988 dist=0.3056 lr=5.0e-04 | ns22: 0.8514 | Av=0.9858 Am=0.7574 In=0.8500 Ma=1.0000 [128s] *ns22 *macro
#     Ep03: loss=0.3486 cls=0.0911 dist=0.2576 lr=4.9e-04 | ns22: 0.8780 | Av=0.9960 Am=0.8420 In=0.8574 Ma=1.0000 [128s] *ns22 *macro
#     Ep04: loss=0.3174 cls=0.0868 dist=0.2306 lr=4.8e-04 | ns22: 0.8410 | Av=0.9925 Am=0.8476 In=0.7865 Ma=1.0000 [126s]
#     Ep05: loss=0.2967 cls=0.0831 dist=0.2136 lr=4.6e-04 | ns22: 0.9056 | Av=0.9923 Am=0.8547 In=0.9041 Ma=1.0000 [128s] *ns22 *macro
#     Ep06: loss=0.2817 cls=0.0810 dist=0.2007 lr=4.4e-04 | ns22: 0.9106 | Av=0.9946 Am=0.8711 In=0.9054 Ma=1.0000 [128s] *ns22 *macro
#     Ep07: loss=0.2697 cls=0.0784 dist=0.1913 lr=4.2e-04 | ns22: 0.8943 | Av=0.9925 Am=0.8753 In=0.8697 Ma=1.0000 [128s]
#     Ep08: loss=0.2610 cls=0.0774 dist=0.1836 lr=3.9e-04 | ns22: 0.8940 | Av=0.9954 Am=0.8602 In=0.8755 Ma=1.0000 [129s]
#     Ep09: loss=0.2533 cls=0.0758 dist=0.1775 lr=3.7e-04 | ns22: 0.9001 | Av=0.9939 Am=0.8841 In=0.8766 Ma=1.0000 [128s]
#     Ep10: loss=0.2475 cls=0.0746 dist=0.1730 lr=3.3e-04 | ns22: 0.9150 | Av=0.9875 Am=0.8924 In=0.9097 Ma=1.0000 [127s] *ns22 *macro
#     Ep11: loss=0.2430 cls=0.0750 dist=0.1680 lr=3.0e-04 | ns22: 0.9053 | Av=0.9968 Am=0.8726 In=0.8969 Ma=1.0000 [129s] *macro
#     Ep12: loss=0.2368 cls=0.0739 dist=0.1629 lr=2.7e-04 | ns22: 0.9132 | Av=0.9962 Am=0.8955 In=0.8987 Ma=1.0000 [127s]
#     Ep13: loss=0.2331 cls=0.0731 dist=0.1600 lr=2.3e-04 | ns22: 0.9179 | Av=0.9955 Am=0.8862 In=0.9155 Ma=1.0000 [129s] *ns22
#     Ep14: loss=0.2285 cls=0.0719 dist=0.1566 lr=2.0e-04 | ns22: 0.9034 | Av=0.9947 Am=0.8750 In=0.8905 Ma=1.0000 [130s]
#     Ep15: loss=0.2247 cls=0.0716 dist=0.1531 lr=1.7e-04 | ns22: 0.9101 | Av=0.9955 Am=0.8740 In=0.9071 Ma=1.0000 [131s] *macro
#     Ep16: loss=0.2227 cls=0.0716 dist=0.1511 lr=1.4e-04 | ns22: 0.9117 | Av=0.9936 Am=0.8896 In=0.9003 Ma=1.0000 [131s] *macro
#     Ep17: loss=0.2201 cls=0.0714 dist=0.1487 lr=1.1e-04 | ns22: 0.9104 | Av=0.9955 Am=0.8894 In=0.8981 Ma=1.0000 [130s] *macro
#     Ep18: loss=0.2179 cls=0.0707 dist=0.1472 lr=8.0e-05 | ns22: 0.9095 | Av=0.9949 Am=0.8897 In=0.8955 Ma=1.0000 [130s]
#     Early stopping triggered after 5 epochs without improvement.
# --- Starting Greedy Soup based on macro_auc_all ---
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
#   Model 1 (Epoch score: 0.9085) added! New macro AUC: 0.9101
#   Model 2 rejected. Temp macro AUC: 0.9087
#   Model 3 rejected. Temp macro AUC: 0.9066
#   Model 4 rejected. Temp macro AUC: 0.9049
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# W0430 09:23:41.235000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:23:41.235000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:23:41.236000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 09:23:41.237000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# W0430 09:23:44.578000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:23:44.579000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:23:44.579000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 09:23:44.580000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#   ONNX verify: max|diff|=2.340e-03
#   Exported souped_sed_distill_fold0.onnx (0.6 MB)
#
# ============================================================
# FOLD 1
# ============================================================
#   Streams: {'focal': 28908, 'sc': 602}  steps/ep: 461
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# Perch ONNX loaded: embed_idx=0
#     Ep00: loss=1.0556 cls=0.4084 dist=0.6472 lr=2.6e-04 | ns22: 0.7005 | Av=0.7514 Am=0.9186 In=0.5940 Ma=0.8218 [175s] *ns22 *macro
#     Ep01: loss=0.5343 cls=0.1200 dist=0.4143 lr=5.0e-04 | ns22: 0.7270 | Av=0.8335 Am=0.9875 In=0.5771 Ma=0.8341 [142s] *ns22 *macro
#     Ep02: loss=0.4065 cls=0.0988 dist=0.3077 lr=5.0e-04 | ns22: 0.8265 | Av=0.8538 Am=0.9750 In=0.7494 Ma=0.9483 [132s] *ns22 *macro
#     Ep03: loss=0.3501 cls=0.0913 dist=0.2588 lr=4.9e-04 | ns22: 0.8471 | Av=0.8938 Am=0.9875 In=0.8064 Ma=0.7829 [133s] *ns22 *macro
#     Ep04: loss=0.3188 cls=0.0861 dist=0.2328 lr=4.8e-04 | ns22: 0.8730 | Av=0.9180 Am=0.6750 In=0.8631 Ma=0.9828 [130s] *ns22 *macro
#     Ep05: loss=0.2988 cls=0.0834 dist=0.2154 lr=4.6e-04 | ns22: 0.8645 | Av=0.9057 Am=0.8000 In=0.8210 Ma=0.9857 [130s]
#     Ep06: loss=0.2829 cls=0.0812 dist=0.2017 lr=4.4e-04 | ns22: 0.8874 | Av=0.9252 Am=0.8250 In=0.8570 Ma=0.9872 [131s] *ns22
#     Ep07: loss=0.2714 cls=0.0793 dist=0.1921 lr=4.2e-04 | ns22: 0.8903 | Av=0.9470 Am=0.8500 In=0.8465 Ma=0.9728 [131s] *ns22 *macro
#     Ep08: loss=0.2622 cls=0.0774 dist=0.1848 lr=3.9e-04 | ns22: 0.8449 | Av=0.9465 Am=0.5625 In=0.8108 Ma=0.9778 [131s]
#     Ep09: loss=0.2551 cls=0.0766 dist=0.1785 lr=3.7e-04 | ns22: 0.8947 | Av=0.9396 Am=0.9375 In=0.8429 Ma=0.9550 [132s] *ns22
#     Ep10: loss=0.2476 cls=0.0751 dist=0.1724 lr=3.3e-04 | ns22: 0.8876 | Av=0.9377 Am=0.7875 In=0.8613 Ma=0.9651 [134s]
#     Ep11: loss=0.2436 cls=0.0743 dist=0.1692 lr=3.0e-04 | ns22: 0.8638 | Av=0.9362 Am=0.6250 In=0.8399 Ma=0.9907 [134s]
#     Ep12: loss=0.2388 cls=0.0743 dist=0.1645 lr=2.7e-04 | ns22: 0.8667 | Av=0.9472 Am=0.7375 In=0.8207 Ma=0.9693 [133s]
#     Ep13: loss=0.2337 cls=0.0729 dist=0.1608 lr=2.3e-04 | ns22: 0.8881 | Av=0.9661 Am=0.7375 In=0.8593 Ma=0.9622 [134s]
#     Ep14: loss=0.2291 cls=0.0719 dist=0.1572 lr=2.0e-04 | ns22: 0.8642 | Av=0.9623 Am=0.5875 In=0.8389 Ma=0.9544 [134s]
#     Early stopping triggered after 5 epochs without improvement.
# --- Starting Greedy Soup based on macro_auc_all ---
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
#   Model 1 rejected. Temp macro AUC: 0.9475
#   Model 2 (Epoch score: 0.9418) added! New macro AUC: 0.9500
#   Model 3 rejected. Temp macro AUC: 0.9492
#   Model 4 rejected. Temp macro AUC: 0.9496
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# W0430 09:57:46.007000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:57:46.007000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:57:46.008000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 09:57:46.008000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# W0430 09:57:49.404000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:57:49.405000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 09:57:49.405000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 09:57:49.406000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#   ONNX verify: max|diff|=2.115e-03
#   Exported souped_sed_distill_fold1.onnx (0.6 MB)
#
# ============================================================
# FOLD 2
# ============================================================
#   Streams: {'focal': 28891, 'sc': 593}  steps/ep: 460
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# Perch ONNX loaded: embed_idx=0
#     Ep00: loss=1.0226 cls=0.3765 dist=0.6461 lr=2.6e-04 | ns22: 0.7402 | Av=0.7391 Am=0.7610 In=0.7241 Ma=0.7708 [135s] *ns22 *macro
#     Ep01: loss=0.5355 cls=0.1204 dist=0.4151 lr=5.0e-04 | ns22: 0.8218 | Av=0.9000 Am=0.9529 In=0.6416 Ma=1.0000 [133s] *ns22 *macro
#     Ep02: loss=0.4060 cls=0.0988 dist=0.3071 lr=5.0e-04 | ns22: 0.8544 | Av=0.9385 Am=0.9724 In=0.6828 Ma=1.0000 [132s] *ns22 *macro
#     Ep03: loss=0.3494 cls=0.0913 dist=0.2581 lr=4.9e-04 | ns22: 0.8286 | Av=0.9027 Am=0.9268 In=0.6711 Ma=1.0000 [132s]
#     Ep04: loss=0.3189 cls=0.0867 dist=0.2322 lr=4.8e-04 | ns22: 0.8582 | Av=0.9464 Am=0.9755 In=0.6841 Ma=1.0000 [133s] *ns22 *macro
#     Ep05: loss=0.2982 cls=0.0835 dist=0.2147 lr=4.6e-04 | ns22: 0.8536 | Av=0.9320 Am=0.9827 In=0.6779 Ma=1.0000 [133s] *macro
#     Ep06: loss=0.2830 cls=0.0813 dist=0.2017 lr=4.4e-04 | ns22: 0.8457 | Av=0.9321 Am=0.9805 In=0.6590 Ma=1.0000 [133s]
#     Ep07: loss=0.2709 cls=0.0787 dist=0.1922 lr=4.2e-04 | ns22: 0.8628 | Av=0.9315 Am=0.9869 In=0.7066 Ma=1.0000 [133s] *ns22
#     Ep08: loss=0.2631 cls=0.0778 dist=0.1853 lr=3.9e-04 | ns22: 0.8815 | Av=0.9504 Am=0.9845 In=0.7360 Ma=1.0000 [132s] *ns22
#     Ep09: loss=0.2553 cls=0.0770 dist=0.1783 lr=3.7e-04 | ns22: 0.8669 | Av=0.9266 Am=0.9942 In=0.7132 Ma=1.0000 [133s]
#     Ep10: loss=0.2488 cls=0.0758 dist=0.1730 lr=3.3e-04 | ns22: 0.8976 | Av=0.9516 Am=0.9776 In=0.7812 Ma=1.0000 [134s] *ns22 *macro
#     Ep11: loss=0.2427 cls=0.0746 dist=0.1681 lr=3.0e-04 | ns22: 0.8756 | Av=0.9349 Am=0.9846 In=0.7331 Ma=1.0000 [131s]
#     Ep12: loss=0.2378 cls=0.0742 dist=0.1636 lr=2.7e-04 | ns22: 0.8793 | Av=0.9418 Am=0.9857 In=0.7354 Ma=1.0000 [134s]
#     Ep13: loss=0.2338 cls=0.0734 dist=0.1604 lr=2.3e-04 | ns22: 0.8860 | Av=0.9491 Am=0.9838 In=0.7485 Ma=1.0000 [132s]
#     Ep14: loss=0.2295 cls=0.0723 dist=0.1572 lr=2.0e-04 | ns22: 0.8830 | Av=0.9495 Am=0.9895 In=0.7367 Ma=1.0000 [133s]
#     Ep15: loss=0.2269 cls=0.0726 dist=0.1543 lr=1.7e-04 | ns22: 0.8768 | Av=0.9506 Am=0.9918 In=0.7177 Ma=1.0000 [133s]
#     Early stopping triggered after 5 epochs without improvement.
# --- Starting Greedy Soup based on macro_auc_all ---
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
#   Model 1 rejected. Temp macro AUC: 0.9091
#   Model 2 (Epoch score: 0.9047) added! New macro AUC: 0.9115
#   Model 3 rejected. Temp macro AUC: 0.9080
#   Model 4 rejected. Temp macro AUC: 0.9095
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# W0430 10:33:20.023000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 10:33:20.024000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 10:33:20.024000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 10:33:20.025000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# W0430 10:33:23.431000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 10:33:23.432000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 10:33:23.432000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 10:33:23.433000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#   ONNX verify: max|diff|=1.637e-03
#   Exported souped_sed_distill_fold2.onnx (0.6 MB)
#
# ============================================================
# FOLD 3
# ============================================================
#   Streams: {'focal': 28919, 'sc': 590}  steps/ep: 461
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# Perch ONNX loaded: embed_idx=0
#     Ep00: loss=1.0283 cls=0.3835 dist=0.6448 lr=2.6e-04 | ns22: 0.6272 | Av=0.5800 Am=0.7558 In=0.5505 Ma=0.6417 [138s] *ns22 *macro
#     Ep01: loss=0.5363 cls=0.1210 dist=0.4153 lr=5.0e-04 | ns22: 0.7499 | Av=0.7747 Am=0.7038 In=0.7215 Ma=0.9500 [136s] *ns22 *macro
#     Ep02: loss=0.4074 cls=0.0996 dist=0.3079 lr=5.0e-04 | ns22: 0.7934 | Av=0.8868 Am=0.7276 In=0.7340 Ma=0.9750 [137s] *ns22 *macro
#     Ep03: loss=0.3491 cls=0.0913 dist=0.2578 lr=4.9e-04 | ns22: 0.8267 | Av=0.8625 Am=0.8188 In=0.7819 Ma=0.9958 [137s] *ns22 *macro
#     Ep04: loss=0.3196 cls=0.0869 dist=0.2327 lr=4.8e-04 | ns22: 0.8234 | Av=0.8777 Am=0.8277 In=0.7580 Ma=0.9833 [132s] *macro
#     Ep05: loss=0.2989 cls=0.0838 dist=0.2151 lr=4.6e-04 | ns22: 0.8576 | Av=0.9326 Am=0.8480 In=0.7834 Ma=1.0000 [134s] *ns22 *macro
#     Ep06: loss=0.2828 cls=0.0813 dist=0.2014 lr=4.4e-04 | ns22: 0.8459 | Av=0.8901 Am=0.8490 In=0.7872 Ma=0.9958 [133s]
#     Ep07: loss=0.2710 cls=0.0787 dist=0.1923 lr=4.2e-04 | ns22: 0.8487 | Av=0.9462 Am=0.8400 In=0.7492 Ma=0.9958 [134s]
#     Ep08: loss=0.2628 cls=0.0783 dist=0.1846 lr=3.9e-04 | ns22: 0.8850 | Av=0.9598 Am=0.8612 In=0.8248 Ma=0.9833 [134s] *ns22 *macro
#     Ep09: loss=0.2546 cls=0.0766 dist=0.1780 lr=3.7e-04 | ns22: 0.8864 | Av=0.9402 Am=0.8681 In=0.8368 Ma=1.0000 [135s] *ns22 *macro
#     Ep10: loss=0.2471 cls=0.0748 dist=0.1724 lr=3.3e-04 | ns22: 0.8801 | Av=0.9612 Am=0.8791 In=0.7931 Ma=0.9958 [134s]
#     Ep11: loss=0.2429 cls=0.0748 dist=0.1680 lr=3.0e-04 | ns22: 0.8991 | Av=0.9571 Am=0.8475 In=0.8661 Ma=1.0000 [133s] *ns22
#     Ep12: loss=0.2378 cls=0.0736 dist=0.1642 lr=2.7e-04 | ns22: 0.8963 | Av=0.9639 Am=0.8539 In=0.8492 Ma=1.0000 [134s]
#     Ep13: loss=0.2335 cls=0.0731 dist=0.1604 lr=2.3e-04 | ns22: 0.9077 | Av=0.9558 Am=0.8632 In=0.8798 Ma=1.0000 [135s] *ns22
#     Ep14: loss=0.2294 cls=0.0725 dist=0.1570 lr=2.0e-04 | ns22: 0.9050 | Av=0.9591 Am=0.8749 In=0.8625 Ma=1.0000 [136s] *macro
#     Ep15: loss=0.2259 cls=0.0718 dist=0.1542 lr=1.7e-04 | ns22: 0.9026 | Av=0.9624 Am=0.8565 In=0.8658 Ma=0.9958 [134s]
#     Ep16: loss=0.2229 cls=0.0714 dist=0.1514 lr=1.4e-04 | ns22: 0.9092 | Av=0.9705 Am=0.8612 In=0.8736 Ma=0.9958 [135s] *ns22
#     Ep17: loss=0.2204 cls=0.0712 dist=0.1491 lr=1.1e-04 | ns22: 0.9054 | Av=0.9653 Am=0.8530 In=0.8724 Ma=1.0000 [133s]
#     Ep18: loss=0.2178 cls=0.0708 dist=0.1471 lr=8.0e-05 | ns22: 0.9069 | Av=0.9660 Am=0.8530 In=0.8763 Ma=0.9958 [133s]
#     Ep19: loss=0.2157 cls=0.0705 dist=0.1452 lr=5.7e-05 | ns22: 0.9015 | Av=0.9646 Am=0.8447 In=0.8684 Ma=0.9958 [136s]
#     Ep20: loss=0.2149 cls=0.0709 dist=0.1440 lr=3.7e-05 | ns22: 0.9103 | Av=0.9660 Am=0.8524 In=0.8857 Ma=0.9958 [135s] *ns22
#     Ep21: loss=0.2134 cls=0.0698 dist=0.1436 lr=2.2e-05 | ns22: 0.9031 | Av=0.9606 Am=0.8528 In=0.8709 Ma=0.9958 [134s]
#     Ep22: loss=0.2128 cls=0.0703 dist=0.1424 lr=1.0e-05 | ns22: 0.9023 | Av=0.9579 Am=0.8501 In=0.8727 Ma=0.9958 [136s]
#     Ep23: loss=0.2122 cls=0.0701 dist=0.1421 lr=3.3e-06 | ns22: 0.9043 | Av=0.9617 Am=0.8518 In=0.8736 Ma=0.9958 [134s]
#     Ep24: loss=0.2111 cls=0.0697 dist=0.1415 lr=1.0e-06 | ns22: 0.9050 | Av=0.9617 Am=0.8505 In=0.8764 Ma=0.9958 [134s]
# --- Starting Greedy Soup based on macro_auc_all ---
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
#   Model 1 (Epoch score: 0.9386) added! New macro AUC: 0.9404
#   Model 2 rejected. Temp macro AUC: 0.9402
#   Model 3 rejected. Temp macro AUC: 0.9401
#   Model 4 rejected. Temp macro AUC: 0.9395
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# W0430 11:29:36.524000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 11:29:36.524000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 11:29:36.525000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 11:29:36.525000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# W0430 11:29:40.030000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 11:29:40.031000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 11:29:40.031000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 11:29:40.032000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#   ONNX verify: max|diff|=1.703e-03
#   Exported souped_sed_distill_fold3.onnx (0.6 MB)
#
# ============================================================
# FOLD 4
# ============================================================
#   Streams: {'focal': 28916, 'sc': 587}  steps/ep: 460
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# Perch ONNX loaded: embed_idx=0
#     Ep00: loss=1.0226 cls=0.3750 dist=0.6477 lr=2.6e-04 | ns22: 0.7052 | Av=0.5787 Am=0.5754 In=0.8530 Ma=0.4352 [134s] *ns22 *macro
#     Ep01: loss=0.5342 cls=0.1215 dist=0.4127 lr=5.0e-04 | ns22: 0.8211 | Av=0.8073 Am=0.7904 In=0.8266 Ma=0.9722 [133s] *ns22 *macro
#     Ep02: loss=0.4056 cls=0.0993 dist=0.3063 lr=5.0e-04 | ns22: 0.8777 | Av=0.9178 Am=0.8183 In=0.8432 Ma=1.0000 [133s] *ns22 *macro
#     Ep03: loss=0.3487 cls=0.0904 dist=0.2583 lr=4.9e-04 | ns22: 0.8840 | Av=0.9425 Am=0.8144 In=0.8514 Ma=0.9907 [133s] *ns22 *macro
#     Ep04: loss=0.3193 cls=0.0864 dist=0.2328 lr=4.8e-04 | ns22: 0.8949 | Av=0.9150 Am=0.8366 In=0.8854 Ma=1.0000 [135s] *ns22
#     Ep05: loss=0.2979 cls=0.0830 dist=0.2149 lr=4.6e-04 | ns22: 0.8779 | Av=0.9616 Am=0.8045 In=0.8263 Ma=1.0000 [135s]
#     Ep06: loss=0.2836 cls=0.0809 dist=0.2027 lr=4.4e-04 | ns22: 0.8966 | Av=0.9502 Am=0.8128 In=0.8625 Ma=1.0000 [134s] *ns22
#     Ep07: loss=0.2707 cls=0.0787 dist=0.1920 lr=4.2e-04 | ns22: 0.9036 | Av=0.9118 Am=0.8272 In=0.9053 Ma=1.0000 [134s] *ns22 *macro
#     Ep08: loss=0.2619 cls=0.0773 dist=0.1846 lr=3.9e-04 | ns22: 0.9081 | Av=0.9765 Am=0.8252 In=0.8617 Ma=1.0000 [133s] *ns22 *macro
#     Ep09: loss=0.2539 cls=0.0760 dist=0.1779 lr=3.7e-04 | ns22: 0.9035 | Av=0.9665 Am=0.8098 In=0.8642 Ma=1.0000 [134s] *macro
#     Ep10: loss=0.2474 cls=0.0746 dist=0.1728 lr=3.3e-04 | ns22: 0.9104 | Av=0.9712 Am=0.8389 In=0.8672 Ma=1.0000 [135s] *ns22
#     Ep11: loss=0.2429 cls=0.0743 dist=0.1686 lr=3.0e-04 | ns22: 0.9056 | Av=0.9752 Am=0.8210 In=0.8583 Ma=1.0000 [134s]
#     Ep12: loss=0.2365 cls=0.0731 dist=0.1634 lr=2.7e-04 | ns22: 0.9147 | Av=0.9670 Am=0.8406 In=0.8802 Ma=1.0000 [134s] *ns22
#     Ep13: loss=0.2329 cls=0.0727 dist=0.1602 lr=2.3e-04 | ns22: 0.9085 | Av=0.9703 Am=0.8289 In=0.8666 Ma=1.0000 [133s]
#     Ep14: loss=0.2283 cls=0.0717 dist=0.1566 lr=2.0e-04 | ns22: 0.9128 | Av=0.9675 Am=0.8245 In=0.8801 Ma=1.0000 [134s] *macro
#     Ep15: loss=0.2265 cls=0.0720 dist=0.1545 lr=1.7e-04 | ns22: 0.9184 | Av=0.9636 Am=0.8199 In=0.8978 Ma=1.0000 [133s] *ns22 *macro
#     Ep16: loss=0.2230 cls=0.0713 dist=0.1517 lr=1.4e-04 | ns22: 0.9151 | Av=0.9636 Am=0.8288 In=0.8875 Ma=1.0000 [134s] *macro
#     Ep17: loss=0.2200 cls=0.0710 dist=0.1491 lr=1.1e-04 | ns22: 0.9074 | Av=0.9630 Am=0.8203 In=0.8730 Ma=1.0000 [135s]
#     Ep18: loss=0.2183 cls=0.0710 dist=0.1473 lr=8.0e-05 | ns22: 0.9134 | Av=0.9646 Am=0.8195 In=0.8857 Ma=1.0000 [134s]
#     Ep19: loss=0.2158 cls=0.0701 dist=0.1456 lr=5.7e-05 | ns22: 0.9172 | Av=0.9715 Am=0.8241 In=0.8871 Ma=1.0000 [135s]
#     Ep20: loss=0.2144 cls=0.0701 dist=0.1443 lr=3.7e-05 | ns22: 0.9222 | Av=0.9691 Am=0.8268 In=0.8998 Ma=1.0000 [136s] *ns22
#     Ep21: loss=0.2135 cls=0.0700 dist=0.1435 lr=2.2e-05 | ns22: 0.9188 | Av=0.9674 Am=0.8332 In=0.8915 Ma=1.0000 [136s]
#     Ep22: loss=0.2126 cls=0.0700 dist=0.1427 lr=1.0e-05 | ns22: 0.9157 | Av=0.9682 Am=0.8260 In=0.8861 Ma=1.0000 [136s]
#     Ep23: loss=0.2116 cls=0.0699 dist=0.1417 lr=3.3e-06 | ns22: 0.9163 | Av=0.9686 Am=0.8264 In=0.8868 Ma=1.0000 [136s]
#     Ep24: loss=0.2106 cls=0.0690 dist=0.1415 lr=1.0e-06 | ns22: 0.9165 | Av=0.9691 Am=0.8281 In=0.8864 Ma=1.0000 [137s]
# --- Starting Greedy Soup based on macro_auc_all ---
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
#   Model 1 (Epoch score: 0.9394) added! New macro AUC: 0.9413
#   Model 2 rejected. Temp macro AUC: 0.9409
#   Model 3 rejected. Temp macro AUC: 0.9406
#   Model 4 rejected. Temp macro AUC: 0.9399
# V2 backbone: (1, 1280, 8, 10)  (C=1280)
# W0430 12:25:46.225000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 12:25:46.225000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 12:25:46.226000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 12:25:46.226000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# W0430 12:25:49.707000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 12:25:49.708000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'rois' from (input, rois, spatial_scale: 'float', pooled_height: 'int', pooled_width: 'int', sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0430 12:25:49.709000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0430 12:25:49.709000 2176 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `SEDExportWrapper([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
#   ONNX verify: max|diff|=2.316e-03
#   Exported souped_sed_distill_fold4.onnx (0.6 MB)

# %% [markdown]
# * ns22: サイト「S22」を除外した検証用Soundscapeデータにおける、予測ブレンド（Clip予測とFrame-max予測の平均）のMacro AUCスコアです。S22はラベルノイズが多い既知のサイトであるため、これを除外したこのスコアが主力の評価指標として機能しています。
#
# * 分類（Taxonomy）ごとのAUCスコア: S22を除外したデータにおける、生物分類ごとのMacro AUCスコアです。
#
#     * Av: 鳥類（Aves）
#
#     * Am: 両生類（Amphibia）
#
#     * In: 昆虫類（Insecta）
#
#     * Ma: 哺乳類（Mammalia）

# %% [markdown]
# # S7 — OOF Evaluation

# %%
# =================================================================
# S7 -- EVALUATION SUMMARY
# =================================================================

if MODE != "train":
    print("Skipping evaluation (MODE='infer')")
else:

    has = ~np.isnan(oof_ns22[:, 0])
    if has.sum() > 0:
        r_all = full_eval(Y_SC[has], oof_ns22[has], non_s22_mask_sc[has], TAXON_MASKS)
        print("=" * 60)
        print("OOF RESULTS (best-ns22 checkpoints)")
        print("=" * 60)
        print(f"  macro AUC (all):        {r_all['macro_auc_all']:.4f}")
        print(f"  macro AUC (non-S22):    {r_all['non_s22_macro']:.4f}")
        for t in ["Aves", "Amphibia", "Insecta", "Mammalia"]:
            print(f"    {t:<12}: {r_all.get(f'non_s22_{t}', float('nan')):.4f}")

    # Per-epoch progression
    print("\nPer-epoch pooled non-S22 AUC:")
    fold_true, fold_ns22_m = {}, {}
    for fk in range(N_FOLDS):
        vm = sc_cache_meta["fold"].values == fk
        fold_true[fk] = Y_SC[vm]
        fold_ns22_m[fk] = non_s22_mask_sc[vm]

    n_eps = [len(all_hist[k]["val_preds"]) for k in range(N_FOLDS) if k in all_hist]
    max_ep = min(n_eps) if n_eps else 0
    for ep in range(max_ep):
        pp = np.concatenate([all_hist[k]["val_preds"][ep] for k in range(N_FOLDS) if k in all_hist])
        pt = np.concatenate([fold_true[k] for k in range(N_FOLDS) if k in all_hist])
        pm = np.concatenate([fold_ns22_m[k] for k in range(N_FOLDS) if k in all_hist])
        ns, _ = compute_macro_auc(pt, pp, mask=pm)
        print(f"  Ep{ep:02d}: {ns:.4f}")
# Out:
# ============================================================
# OOF RESULTS (best-ns22 checkpoints)
# ============================================================
#   macro AUC (all):        0.7890
#   macro AUC (non-S22):    0.7186
#     Aves        : 0.8868
#     Amphibia    : 0.7943
#     Insecta     : 0.5247
#     Mammalia    : 0.9335
#
# Per-epoch pooled non-S22 AUC:
#   Ep00: 0.5412
#   Ep01: 0.5835
#   Ep02: 0.6380
#   Ep03: 0.6495
#   Ep04: 0.6725
#   Ep05: 0.6879
#   Ep06: 0.6932
#   Ep07: 0.6936
#   Ep08: 0.7024
#   Ep09: 0.7006
#   Ep10: 0.7089
#   Ep11: 0.7055
#   Ep12: 0.7061
#   Ep13: 0.7127
#   Ep14: 0.7100

# %%
import time
from google.colab import runtime

# 1時間（X秒）待機してから終了する場合
time.sleep(10)
runtime.unassign()
